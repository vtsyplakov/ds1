# %% [markdown]
# # Введение в Jupyter

# %% [markdown]
# Что мы будем сегодня делать?
#
# * Разбееремся с типами ячеек
# * Поработаем с данными в формате .csv

# %%
import csv

# %%
streets = {}

# %%
with open('bus_stops.csv', 'r', encoding='cp1251') as f:
    reader = csv.DictReader(f, delimiter=';')
    for row in reader:
        if row['Street'] in streets:
            streets[row['Street']] += 1
        else:
            streets[row['Street']] = 1
            
streets
# Out:
# {'3-й Дербеневский переулок': 2,
#  'набережная Тараса Шевченко': 2,
#  '3-я Черепковская улица': 5,
#  'улица Сущёвский Вал': 16,
#  'Дубнинская улица': 29,
#  'улица 800-летия Москвы': 13,
#  'Дмитровское шоссе': 69,
#  'Локомотивный проезд': 7,
#  'Большая Академическая улица': 25,
#  'улица Зои и Александра Космодемьянских': 14,
#  'Путейская улица': 5,
#  'Ангарская улица': 14,
#  'Коровинское шоссе': 24,
#  'Клязьминская улица': 12,
#  'улица Линии Октябрьской Железной Дороги': 6,
#  'Старопетровский проезд': 8,
#  'улица Клары Цеткин': 5,
#  'Михалковская улица': 15,
#  'Онежская улица': 11,
#  'Петрозаводская улица': 8,
#  'Беломорская улица': 10,
#  'Смольная улица': 17,
#  'Фестивальная улица': 24,
#  'Бескудниковский бульвар': 21,
#  'Коптевский бульвар': 4,
#  'Коптевская улица': 11,
#  'Кронштадтский бульвар': 21,
#  'Нарвская улица': 5,
#  '3-й Лихачёвский переулок': 1,
#  '4-й Лихачёвский переулок': 2,
#  'Автомоторная улица': 6,
#  '4-й Новомихалковский проезд': 4,
#  'Митинская улица': 14,
#  'улица Дыбенко': 10,
#  'Зеленоградская улица': 14,
#  'улица Академика Курчатова': 5,
#  'Сосновая улица': 3,
#  'Пехотная улица': 2,
#  '1-й Волоколамский проезд': 4,
#  'улица Усиевича': 4,
#  'Планетная улица': 7,
#  'Петровско-Разумовская аллея': 6,
#  'Часовая улица': 4,
#  '2-й Пехотный переулок': 2,
#  'Авангардная улица': 6,
#  'Флотская улица': 13,
#  'Солнечногорская улица': 6,
#  'Сенежская улица': 2,
#  'улица Прянишникова': 4,
#  'Тимирязевская улица': 21,
#  'улица Вучетича': 6,
#  '2-я Хуторская улица': 3,
#  'Петровско-Разумовский проезд': 8,
#  'Ижорская улица': 6,
#  'улица Бусиновская Горка': 4,
#  'Краснополянская улица': 5,
#  'улица Лавочкина': 5,
#  'Бутырская улица': 16,
#  'улица Бутырский Вал': 8,
#  'Новослободская улица': 8,
#  'Херсонская улица': 10,
#  'Волоколамское шоссе': 46,
#  'Ленинградский проспект': 35,
#  'Ботаническая улица': 14,
#  'улица Академика Королёва': 17,
#  'Новомосковская улица': 7,
#  'Звёздный бульвар': 5,
#  '6-й Новоостанкинский проезд': 1,
#  'улица Цандера': 2,
#  'улица Кондратюка': 1,
#  'проспект Мира': 73,
#  'Сусоколовское шоссе': 2,
#  'улица Свободы': 34,
#  'Сходненская улица': 12,
#  'улица Маршала Федоренко': 6,
#  'улица Лужники': 3,
#  'Лужнецкая набережная': 3,
#  'Лужнецкий проезд': 2,
#  'Большая Пироговская улица': 12,
#  'улица Плющиха': 8,
#  'улица Хамовнический Вал': 6,
#  'Смоленская-Сенная площадь': 2,
#  'Новинский бульвар': 4,
#  'улица Красная Пресня': 8,
#  'улица 1905 Года': 6,
#  'Хорошёвское шоссе': 21,
#  'Кудринская площадь': 2,
#  'улица Еланского': 1,
#  'Красностуденческий проезд': 5,
#  'Смоленский бульвар': 4,
#  'улица Берзарина': 12,
#  'улица Расплетина': 5,
#  'улица Маршала Бирюзова': 16,
#  'улица Василия Петушкова': 11,
#  'Светлогорский проезд': 4,
#  'улица Героев Панфиловцев': 37,
#  'Гостиничная улица': 1,
#  'Башиловская улица': 8,
#  'улица Расковой': 4,
#  '5-я улица Ямского Поля': 2,
#  '1-я улица Ямского Поля': 2,
#  'улица Нижняя Масловка': 8,
#  '3-й Нижнелихоборский проезд': 4,
#  'улица Исаковского': 14,
#  'улица Маршала Катукова': 16,
#  'Рублёвское шоссе': 40,
#  'улица Кулакова': 17,
#  '2-я Квесисская улица': 5,
#  'Мякининский проезд': 2,
#  '2-й Крестовский переулок': 1,
#  'Рижская площадь': 4,
#  '4-й Вятский переулок': 5,
#  'Старый Петровско-Разумовский проезд': 4,
#  'бульвар Яна Райниса': 17,
#  'Химкинский бульвар': 6,
#  'улица Куусинена': 11,
#  'улица Маршала Тухачевского': 11,
#  'улица Народного Ополчения': 24,
#  'улица Саляма Адиля': 3,
#  'Карамышевская набережная': 11,
#  'улица Мнёвники': 9,
#  'проспект Маршала Жукова': 23,
#  'Таманская улица': 14,
#  'Карамышевский проезд': 2,
#  'Звенигородское шоссе': 9,
#  'Песчаная площадь': 3,
#  'Новопесчаная улица': 8,
#  'Ленинградское шоссе': 57,
#  'Анадырский проезд': 10,
#  'улица Малыгина': 9,
#  'Изумрудная улица': 10,
#  'Минусинская улица': 3,
#  'улица Коминтерна': 11,
#  'Радужная улица': 10,
#  'Енисейская улица': 22,
#  'проезд Серебрякова': 10,
#  'улица Амундсена': 2,
#  'Туристская улица': 10,
#  'Походный проезд': 7,
#  'Строительный проезд': 4,
#  'проезд Донелайтиса': 8,
#  'улица Фабрициуса': 10,
#  'Лодочная улица': 11,
#  'Вишнёвая улица': 4,
#  'улица Генерала Белобородова': 16,
#  'улица Маршала Конева': 2,
#  'улица Алабяна': 7,
#  'улица Черняховского': 1,
#  'улица Маршала Василевского': 6,
#  'Песчаная улица': 4,
#  'проезд Девичьего Поля': 1,
#  'Смоленская площадь': 2,
#  'площадь Новодевичьего Монастыря': 2,
#  'Ельнинская улица': 8,
#  'проезд без названия': 619,
#  'улица Генерала Глаголева': 6,
#  'Планерная улица': 13,
#  'Снежная улица': 9,
#  'проезд Соломенной Сторожки': 3,
#  'Алёшкинский проезд': 2,
#  'улица Корнейчука': 15,
#  'улица Лескова': 18,
#  'Широкая улица': 23,
#  'улица Бориса Галушкина': 9,
#  'Ростокинский проезд': 6,
#  'Богородское шоссе': 8,
#  'улица Максимова': 3,
#  'улица Рогова': 5,
#  'площадь Академика Курчатова': 2,
#  'Талдомская улица': 4,
#  'Керамический проезд': 4,
#  'Весенняя улица': 2,
#  'Лобненская улица': 9,
#  'Живописная улица': 16,
#  'улица Паршина': 4,
#  'улица Маршала Соколовского': 2,
#  'улица Маршала Новикова': 5,
#  'Авиационная улица': 15,
#  'улица Маршала Вершинина': 1,
#  'улица Твардовского': 11,
#  'Таллинская улица': 18,
#  'Новощукинская улица': 13,
#  'проезд Стратонавтов': 1,
#  'Строгинское шоссе': 6,
#  'Тушинская площадь': 8,
#  'Туркменский проезд': 2,
#  'Одинцовская улица': 3,
#  'Строгинский бульвар': 9,
#  'Ижорский проезд': 3,
#  'Прибрежный проезд': 8,
#  'Неманский проезд': 8,
#  'Гостиничный проезд': 2,
#  'улица Космонавта Волкова': 7,
#  'улица Грачёвка': 2,
#  'улица Академика Бочвара': 2,
#  'улица Гамалеи': 6,
#  'Карельский бульвар': 7,
#  'улица Софьи Ковалевской': 9,
#  '74-й километр Московской Кольцевой Автодороги': 2,
#  '1-й Силикатный проезд': 8,
#  'Шелепихинское шоссе': 4,
#  '3-я Магистральная улица': 5,
#  '4-я Магистральная улица': 6,
#  'улица Нижние Мнёвники': 12,
#  'улица Сергея Эйзенштейна': 3,
#  'улица Вильгельма Пика': 5,
#  'Берёзовая аллея': 9,
#  'Олонецкая улица': 5,
#  'Отрадная улица': 4,
#  'Отрадный проезд': 3,
#  'Сигнальный проезд': 9,
#  'Продольный проезд': 15,
#  'улица Вилиса Лациса': 13,
#  'Причальный проезд': 2,
#  'Шелепихинская набережная': 4,
#  'Большая Филёвская улица': 16,
#  'Минская улица': 15,
#  'улица Фомичёвой': 4,
#  'Осенний бульвар': 10,
#  'улица Крылатские Холмы': 17,
#  'Рубежный проезд': 2,
#  'Беговая улица': 7,
#  'Магистральный переулок': 2,
#  '2-й Хорошёвский проезд': 5,
#  '5-я Магистральная улица': 1,
#  'улица Заморёнова': 7,
#  '3-я Хорошёвская улица': 10,
#  'Ярославское шоссе': 24,
#  '93-й километр Московской Кольцевой Автодороги': 2,
#  '92-й километр Московской Кольцевой Автодороги': 4,
#  '91-й километр Московской Кольцевой Автодороги': 2,
#  '89-й километр Московской Кольцевой Автодороги': 2,
#  '88-й километр Московской Кольцевой Автодороги': 2,
#  '87-й километр Московской Кольцевой Автодороги': 2,
#  '84-й километр Московской Кольцевой Автодороги': 2,
#  '83-й километр Московской Кольцевой Автодороги': 2,
#  'Лианозовский проезд': 5,
#  'Мелиховская улица': 3,
#  'Белозерская улица': 7,
#  'Мурановская улица': 6,
#  'улица Пришвина': 9,
#  'Бибиревская улица': 11,
#  'Алтуфьевское шоссе': 47,
#  'Костромская улица': 8,
#  'Череповецкая улица': 16,
#  'улица Ивана Сусанина': 7,
#  'Осенняя улица': 8,
#  'Крылатская улица': 20,
#  'Осташковская улица': 10,
#  'Псковская улица': 3,
#  'Зональная улица': 2,
#  'Барвихинская улица': 13,
#  'Запорожская улица': 1,
#  'улица Маршала Неделина': 7,
#  'улица Красных Зорь': 9,
#  'Малая Филёвская улица': 12,
#  'Пинский проезд': 2,
#  'улица Барклая': 13,
#  'улица Толбухина': 4,
#  'Можайское шоссе': 13,
#  'Аминьевское шоссе': 16,
#  'Верейская улица': 10,
#  'Рябиновая улица': 30,
#  '2-й Поперечный проезд': 2,
#  'Абрамцевская улица': 12,
#  'улица Плещеева': 8,
#  'улица Конёнкова': 7,
#  'Илимская улица': 6,
#  'улица Говорова': 6,
#  'Вяземская улица': 3,
#  'Сколковское шоссе': 13,
#  'Беловежская улица': 12,
#  'Ярцевская улица': 8,
#  'улица Артамонова': 5,
#  'улица Кубинка': 3,
#  'улица Боженко': 2,
#  'Варшавское шоссе': 174,
#  'Сумская улица': 5,
#  'Кировоградская улица': 27,
#  'улица Красного Маяка': 16,
#  'Вологодский проезд': 5,
#  'улица Лётчика Бабушкина': 17,
#  'улица Менжинского': 18,
#  'Северодвинская улица': 6,
#  'Волгоградский проспект': 47,
#  'Славянский бульвар': 7,
#  'Кременчугская улица': 4,
#  'Гвардейская улица': 3,
#  'Давыдковская улица': 8,
#  'Староможайское шоссе': 3,
#  'Кутузовский проспект': 33,
#  'Большая Дорогомиловская улица': 9,
#  'Бережковская набережная': 8,
#  'Воробьёвское шоссе': 4,
#  'Мосфильмовская улица': 20,
#  'Мичуринский проспект': 41,
#  'улица Косыгина': 15,
#  'Ленинский проспект': 67,
#  'улица Большая Якиманка': 5,
#  'Якиманский проезд': 2,
#  'улица Серафимовича': 3,
#  'Стартовая улица': 12,
#  'проезд Шокальского': 13,
#  'улица Грекова': 7,
#  'Студёный проезд': 8,
#  'проезд Дежнёва': 13,
#  'Тайнинская улица': 6,
#  'Новозаводская улица': 12,
#  'Береговой проезд': 2,
#  'Новофилёвский проезд': 4,
#  'Филёвский бульвар': 9,
#  'Полярная улица': 24,
#  'улица Молодцова': 8,
#  'Ясный проезд': 12,
#  'Северный бульвар': 8,
#  'улица Бестужевых': 7,
#  'Инженерная улица': 6,
#  'Путевой проезд': 8,
#  'улица Декабристов': 15,
#  'улица Хачатуряна': 12,
#  'улица Санникова': 2,
#  'улица Мусоргского': 5,
#  'Челюскинская улица': 6,
#  'Юрловский проезд': 11,
#  'Партизанская улица': 11,
#  'Истринская улица': 3,
#  'Молдавская улица': 4,
#  'Житомирская улица': 1,
#  'Кастанаевская улица': 18,
#  'Молодогвардейская улица': 18,
#  'Заревый проезд': 3,
#  'Сельскохозяйственная улица': 17,
#  'улица Пестеля': 4,
#  'Чертановская улица': 66,
#  'Симферопольский бульвар': 25,
#  'улица 26-ти Бакинских Комиссаров': 9,
#  'Селигерская улица': 1,
#  'Бескудниковский переулок': 1,
#  'улица Академика Янгеля': 6,
#  'Станционная улица': 6,
#  'Россошанский проезд': 4,
#  '3-й Дорожный проезд': 10,
#  'Дорожная улица': 24,
#  'улица Подольских Курсантов': 17,
#  'Мирской переулок': 5,
#  'Холмогорская улица': 2,
#  'улица Римского-Корсакова': 9,
#  'улица Яблочкова': 11,
#  'улица Фонвизина': 5,
#  'улица Милашенкова': 10,
#  'Россошанская улица': 4,
#  'Сумской проезд': 7,
#  '1-я Останкинская улица': 12,
#  'Кольская улица': 6,
#  'Чонгарский бульвар': 13,
#  'Днепропетровская улица': 14,
#  'Печорская улица': 5,
#  'улица Гончарова': 4,
#  'улица Руставели': 9,
#  'Огородный проезд': 11,
#  '17-й проезд Марьиной Рощи': 2,
#  'Шереметьевская улица': 13,
#  '5-й проезд Марьиной Рощи': 2,
#  'Полковая улица': 1,
#  'улица Двинцев': 4,
#  'улица Грузинский Вал': 4,
#  'улица Пресненский Вал': 8,
#  'улица Трёхгорный Вал': 1,
#  'Шмитовский проезд': 13,
#  '2-й Красногвардейский проезд': 3,
#  'Новый Берингов проезд': 4,
#  'улица Сергея Макеева': 4,
#  'Стрелецкая улица': 1,
#  '3-й проезд Марьиной Рощи': 2,
#  'Востряковский проезд': 13,
#  'Булатниковская улица': 9,
#  'Медынская улица': 11,
#  'Харьковская улица': 4,
#  'Булатниковский проезд': 12,
#  'Болотниковская улица': 21,
#  'Большая Тульская улица': 7,
#  'Подольское шоссе': 2,
#  'Павловская улица': 1,
#  'Большая Серпуховская улица': 8,
#  'Серпуховская площадь': 2,
#  'улица Большая Полянка': 8,
#  'Люсиновская улица': 8,
#  'улица Добролюбова': 4,
#  'улица Советской Армии': 6,
#  'Трифоновская улица': 12,
#  'Олимпийский проспект': 7,
#  'улица Дурова': 5,
#  'Самотёчная улица': 2,
#  'Мясницкая улица': 3,
#  'Ростокинская улица': 5,
#  'Малахитовая улица': 8,
#  '1-й Ботанический проезд': 1,
#  'Лазоревый проезд': 2,
#  '2-й Ботанический проезд': 2,
#  'улица Седова': 2,
#  'проезд Русанова': 7,
#  'улица Докукина': 7,
#  'Краснопролетарская улица': 6,
#  'Останкинский проезд': 2,
#  'Селезнёвская улица': 3,
#  'Нахимовский проспект': 33,
#  'Коломенская улица': 11,
#  'улица Новинки': 5,
#  'проспект Андропова': 18,
#  'Нагатинская набережная': 17,
#  'Судостроительная улица': 27,
#  '1-й Нагатинский проезд': 2,
#  'Нагатинская улица': 15,
#  'Ереванская улица': 9,
#  'Кавказский бульвар': 14,
#  'Пролетарский проспект': 13,
#  'Каширское шоссе': 54,
#  'улица Каховка': 15,
#  'улица Намёткина': 3,
#  'Профсоюзная улица': 56,
#  'Страстной бульвар': 3,
#  'Долгоруковская улица': 6,
#  'Большая Переяславская улица': 4,
#  'Каланчёвская улица': 9,
#  'Русаковская улица': 12,
#  'улица Стромынка': 13,
#  'Электрозаводская улица': 12,
#  'Ферганский проезд': 9,
#  'Самаркандский бульвар': 11,
#  'улица Хлобыстова': 13,
#  'Ташкентская улица': 14,
#  'улица Образцова': 4,
#  'Перуновский переулок': 1,
#  'улица Новая Башиловка': 4,
#  'Балаклавский проспект': 19,
#  'улица Обручева': 19,
#  'Ферганская улица': 9,
#  '2-й Грайвороновский проезд': 8,
#  'Грайвороновская улица': 7,
#  'Люблинская улица': 41,
#  'Черноморский бульвар': 9,
#  'Ялтинская улица': 2,
#  'Стрельбищенский переулок': 6,
#  'Оружейный переулок': 2,
#  'Садовая-Триумфальная улица': 2,
#  'улица Павла Корчагина': 9,
#  'Новоалексеевская улица': 4,
#  '3-я Мытищинская улица': 2,
#  'площадь Академика Люльки': 2,
#  'улица Сокольнический Вал': 12,
#  'Поперечный просек': 14,
#  'Краснобогатырская улица': 20,
#  'Семёновская площадь': 3,
#  'Щербаковская улица': 5,
#  'Измайловский проспект': 9,
#  'Первомайская улица': 37,
#  'улица Измайловский Вал': 5,
#  'улица Преображенский Вал': 4,
#  'улица Олений Вал': 4,
#  'Большая Ширяевская улица': 4,
#  'Миллионная улица': 4,
#  'Новорязанская улица': 6,
#  'Бакунинская улица': 10,
#  'Вельяминовская улица': 4,
#  'Ткацкая улица': 8,
#  'Большая Оленья улица': 5,
#  'Халтуринская улица': 4,
#  'Большая Семёновская улица': 6,
#  'Спартаковская улица': 2,
#  'Ивантеевская улица': 16,
#  '1-я Прогонная улица': 1,
#  'Просторная улица': 4,
#  'Игральная улица': 3,
#  'улица Сайкина': 2,
#  'Велозаводская улица': 3,
#  'улица Ленинская Слобода': 4,
#  'улица Мастеркова': 3,
#  'Автозаводская улица': 16,
#  'Битцевский проезд': 6,
#  'Коломенская набережная': 11,
#  'улица Симоновский Вал': 9,
#  'улица Большие Каменщики': 6,
#  'Затонная улица': 5,
#  'Якорная улица': 5,
#  'улица Трофимова': 15,
#  'улица Газопровод': 6,
#  'Бойцовая улица': 8,
#  '4-я Гражданская улица': 2,
#  '1-я Рыбинская улица': 1,
#  'Водопроводный переулок': 2,
#  'Преображенская улица': 4,
#  'проспект Будённого': 33,
#  'улица Бориса Жигулёнкова': 4,
#  '8-я улица Соколиной Горы': 1,
#  'Сиреневый бульвар': 19,
#  'Щёлковский проезд': 2,
#  'Щёлковское шоссе': 37,
#  'Большая Черкизовская улица': 18,
#  'Преображенская площадь': 2,
#  'Вербная улица': 2,
#  'шоссе Энтузиастов': 78,
#  '2-й Полевой переулок': 3,
#  'Котляковская улица': 5,
#  '2-й Котляковский переулок': 3,
#  '1-й Варшавский проезд': 2,
#  'Каширский проезд': 1,
#  'Хабаровская улица': 18,
#  'улица Гастелло': 8,
#  '15-я Парковая улица': 12,
#  'улица Шумкина': 4,
#  'Старая Басманная улица': 7,
#  'улица Земляной Вал': 15,
#  'Костомаровский переулок': 6,
#  'улица Сергия Радонежского': 5,
#  'Новорогожская улица': 5,
#  'Севастопольский проспект': 47,
#  'Азовская улица': 8,
#  'Коломенское шоссе': 2,
#  'улица Садовники': 2,
#  'Коломенский проезд': 10,
#  'улица Академика Миллионщикова': 11,
#  'Зелёный проспект': 39,
#  '3-я Владимирская улица': 12,
#  '3-я Рыбинская улица': 2,
#  'Рабочая улица': 11,
#  'улица Лобачика': 2,
#  'Камчатская улица': 5,
#  'Сахалинская улица': 1,
#  'Уральская улица': 11,
#  '9-я Парковая улица': 12,
#  'Курганская улица': 4,
#  'Уссурийская улица': 6,
#  'Измайловский бульвар': 15,
#  '3-я Парковая улица': 12,
#  'улица Радио': 8,
#  'Бауманская улица': 12,
#  'Протопоповский переулок': 9,
#  'Делегатская улица': 1,
#  '3-й Самотёчный переулок': 5,
#  'улица Достоевского': 3,
#  'Ольховская улица': 2,
#  'Красноказарменная улица': 19,
#  'Байкальская улица': 15,
#  'Чусовская улица': 4,
#  'Иркутская улица': 3,
#  '2-й Иртышский проезд': 5,
#  'улица Бирюсинка': 7,
#  'Амурская улица': 10,
#  'Одесская улица': 4,
#  'улица Дмитрия Ульянова': 17,
#  'Нагорная улица': 15,
#  'Красноярская улица': 6,
#  'Алтайская улица': 13,
#  'Спартаковская площадь': 1,
#  'улица Молостовых': 11,
#  'Свободный проспект': 25,
#  'Вешняковская улица': 21,
#  'улица Красный Казанец': 16,
#  'Саянская улица': 9,
#  'улица Сталеваров': 16,
#  'улица Старый Гай': 4,
#  'Кетчерская улица': 10,
#  'Напольный проезд': 4,
#  'Снайперская улица': 3,
#  'улица Молдагуловой': 12,
#  'Фрязевская улица': 6,
#  'Мартеновская улица': 6,
#  'Новогиреевская улица': 14,
#  'Перовская улица': 21,
#  'Кусковская улица': 11,
#  'улица Плющева': 6,
#  'Электродная улица': 5,
#  'улица Уткина': 3,
#  'Окружной проезд': 13,
#  'Вольная улица': 6,
#  'Федеративный проспект': 14,
#  'улица Металлургов': 5,
#  '2-я Владимирская улица': 11,
#  'улица Плеханова': 14,
#  'Кусковский тупик': 1,
#  'улица Лазо': 5,
#  'Московский проспект': 11,
#  'Ломоносовский проспект': 32,
#  '1-я Владимирская улица': 10,
#  'Челябинская улица': 7,
#  'Большой Купавенский проезд': 7,
#  'Малый Купавенский проезд': 2,
#  '16-я Парковая улица': 9,
#  '106-й километр Московской Кольцевой Автодороги': 2,
#  '108-й километр Московской Кольцевой Автодороги': 2,
#  'улица Юности': 18,
#  'улица Паперника': 3,
#  'Рязанский проспект': 39,
#  'Монтажная улица': 8,
#  'Открытое шоссе': 26,
#  'Измайловское шоссе': 6,
#  'улица Чечулина': 8,
#  'Реутовская улица': 10,
#  'аллея Жемчуговой': 6,
#  'улица Академика Скрябина': 12,
#  'Электролитный проезд': 4,
#  'улица Ремизова': 5,
#  'проезд Карамзина': 13,
#  'Голубинская улица': 20,
#  'Ясногорская улица': 4,
#  'улица Айвазовского': 4,
#  'Тарусская улица': 5,
#  '5-я улица Соколиной Горы': 2,
#  'Яснополянская улица': 2,
#  'улица Михайлова': 11,
#  'улица Коновалова': 4,
#  'Кузьминская улица': 4,
#  'улица Миклухо-Маклая': 22,
#  'улица Введенского': 14,
#  'Нижегородская улица': 16,
#  'Таганская улица': 6,
#  'Оршанская улица': 2,
#  'улица Маршала Тимошенко': 6,
#  'Кунцевская улица': 2,
#  'Полоцкая улица': 3,
#  'улица Ивана Франко': 9,
#  'улица Василия Ботылёва': 5,
#  'Обводное шоссе': 3,
#  'улица Академика Павлова': 8,
#  'Новоясеневский проспект': 33,
#  'Литовский бульвар': 14,
#  '2-я Мякининская улица': 1,
#  'Бобруйская улица': 5,
#  'улица Екатерины Будановой': 2,
#  'улица Коцюбинского': 2,
#  'Никитский бульвар': 2,
#  '1-й Поперечный проезд': 2,
#  'улица Зацепский Вал': 4,
#  'улица Новый Арбат': 9,
#  '2-я улица Машиностроения': 11,
#  '1-я улица Машиностроения': 6,
#  'улица Вострухина': 3,
#  'Сормовская улица': 4,
#  '7-я Парковая улица': 5,
#  '5-я Парковая улица': 7,
#  'Зубовская улица': 2,
#  'улица Пречистенка': 7,
#  'Гоголевский бульвар': 6,
#  'улица Юных Ленинцев': 23,
#  'Таганская площадь': 3,
#  'Верхняя Радищевская улица': 3,
#  'Яузская улица': 4,
#  'Москворецкая набережная': 6,
#  'Кремлёвская набережная': 2,
#  'Пречистенская набережная': 2,
#  'Подгорская набережная': 1,
#  'Нижняя Радищевская улица': 2,
#  'улица Александра Солженицына': 3,
#  'Николоямская улица': 10,
#  'Андроньевский проезд': 2,
#  'Волочаевская улица': 13,
#  'Душинская улица': 2,
#  'Главная улица': 1,
#  'Воронцовская улица': 6,
#  '1-я Дубровская улица': 8,
#  'Шарикоподшипниковская улица': 12,
#  '1-й Сетуньский проезд': 2,
#  '4-й Сетуньский проезд': 1,
#  '2-й Сетуньский проезд': 2,
#  'улица Покровка': 8,
#  'улица Маросейка': 2,
#  'Авиамоторная улица': 24,
#  '2-я Кабельная улица': 1,
#  '2-й Кабельный проезд': 1,
#  'Славянская площадь': 6,
#  'Новочерёмушкинская улица': 17,
#  'проезд Стройкомбината': 4,
#  'Очаковское шоссе': 6,
#  'Матвеевская улица': 8,
#  'Веерная улица': 10,
#  'Нежинская улица': 10,
#  'Староволынская улица': 6,
#  'проспект Вернадского': 63,
#  'Красноармейская улица': 7,
#  'Тверской бульвар': 6,
#  'улица Гарибальди': 10,
#  'улица Архитектора Власова': 9,
#  'Комсомольский проспект': 23,
#  'улица Остоженка': 6,
#  'Подольская улица': 6,
#  'улица Перерва': 27,
#  'улица Нижние Поля': 8,
#  'Волжский бульвар': 25,
#  'Саратовская улица': 6,
#  'улица Лобачевского': 23,
#  'Керченская улица': 4,
#  'Окская улица': 8,
#  'улица Фёдора Полетаева': 8,
#  'Жигулёвская улица': 3,
#  'улица Шкулёва': 4,
#  'Университетский проспект': 14,
#  'Семёновский проезд': 7,
#  'улица Семёновский Вал': 2,
#  'Доброслободская улица': 6,
#  'Новая Басманная улица': 7,
#  'Красноворотский проезд': 1,
#  'Белореченская улица': 15,
#  'Краснодарская улица': 20,
#  'улица Полбина': 15,
#  'Шоссейная улица': 34,
#  'улица Гурьянова': 16,
#  'Перовское шоссе': 10,
#  'шоссе Фрезер': 12,
#  '5-я Кабельная улица': 7,
#  'Новочеркасский бульвар': 14,
#  'Донецкая улица': 9,
#  'улица Олеко Дундича': 2,
#  'улица Маршала Голованова': 7,
#  'улица Горбунова': 7,
#  'улица Судакова': 5,
#  'Краснодонская улица': 19,
#  'Южнопортовая улица': 20,
#  'улица Коштоянца': 7,
#  'улица Удальцова': 18,
#  'Багратионовский проезд': 4,
#  'улица Полосухина': 1,
#  'Батайский проезд': 13,
#  'Ставропольская улица': 22,
#  '13-я Парковая улица': 3,
#  'Измайловская площадь': 2,
#  'Измайловский проезд': 2,
#  'Никитинская улица': 6,
#  '3-я Прядильная улица': 1,
#  '1-я Парковая улица': 2,
#  'Тихорецкий бульвар': 5,
#  'улица Рогожский Вал': 6,
#  'Абельмановская улица': 3,
#  '3-й Крутицкий переулок': 8,
#  'Солдатская улица': 2,
#  'Угрешская улица': 11,
#  'Большая Андроньевская улица': 4,
#  'Зеленодольский проезд': 2,
#  'улица Академика Волгина': 9,
#  'улица Островитянова': 22,
#  'проспект 60-летия Октября': 11,
#  'Садовая-Черногрязская улица': 3,
#  'Лермонтовская площадь': 2,
#  'Садовая-Спасская улица': 4,
#  'Малая Сухаревская площадь': 3,
#  'Самотёчная площадь': 2,
#  'Садовая-Самотёчная улица': 4,
#  'Большая Садовая улица': 2,
#  'Садовая-Кудринская улица': 6,
#  'Зубовский бульвар': 4,
#  'улица Крымский Вал': 3,
#  'Валовая улица': 3,
#  'Большой Краснохолмский мост': 2,
#  'улица Пржевальского': 4,
#  'Большая Очаковская улица': 13,
#  'Никулинская улица': 10,
#  'Банный переулок': 2,
#  'Новосущёвский переулок': 4,
#  'Минаевский переулок': 2,
#  'улица Николая Химушина': 4,
#  'улица Академика Челомея': 3,
#  'улица Новаторов': 10,
#  'улица Воронцовские Пруды': 1,
#  'Вильнюсская улица': 4,
#  'Озёрная улица': 12,
#  'улица Бутлерова': 7,
#  'Мытная улица': 8,
#  'улица Шухова': 1,
#  'улица Академика Пилюгина': 12,
#  'улица Кравченко': 10,
#  'улица Воейкова': 2,
#  'улица Михаила Певцова': 2,
#  'улица Семёнова-Тян-Шанского': 2,
#  'Лубянская площадь': 5,
#  'Устьинская набережная': 1,
#  'улица Марии Ульяновой': 5,
#  'улица Академика Хохлова': 4,
#  'улица Лебедева': 5,
#  'улица Паустовского': 4,
#  'Борисовский проезд': 12,
#  'Смоленская улица': 2,
#  'проезд Нансена': 2,
#  'Грузинский переулок': 1,
#  'Ясеневая улица': 17,
#  'Фрунзенская набережная': 14,
#  'Сущёвская улица': 5,
#  'Нововоротниковский переулок': 1,
#  'Большая Грузинская улица': 6,
#  'Малая Грузинская улица': 6,
#  'Конюшковская улица': 4,
#  'улица Барышиха': 20,
#  'улица Борисовские Пруды': 20,
#  'Малая Андроньевская улица': 2,
#  'Братеевская улица': 11,
#  'Хордовый проезд': 6,
#  'Паромная улица': 5,
#  'Дубининская улица': 14,
#  'Холодильный переулок': 6,
#  'улица Даниловский Вал': 4,
#  'Елецкая улица': 5,
#  'площадь Крестьянская Застава': 2,
#  'Воронежская улица': 13,
#  'Сокольническая площадь': 2,
#  'Иловайская улица': 6,
#  'Верхняя Красносельская улица': 9,
#  'Липецкая улица': 19,
#  'Бакинская улица': 8,
#  'улица Москворечье': 10,
#  'Промышленная улица': 8,
#  'Деловая улица': 2,
#  'улица Кошкина': 3,
#  'Кантемировская улица': 15,
#  'улица Бехтерева': 11,
#  'Севанская улица': 8,
#  'Ряжская улица': 4,
#  'Бирюлёвская улица': 12,
#  'Касимовская улица': 5,
#  'Лебедянская улица': 15,
#  'Загорьевская улица': 5,
#  'Михневская улица': 8,
#  'улица Серпуховский Вал': 11,
#  'Загорьевский проезд': 8,
#  'Каспийская улица': 18,
#  'улица Медиков': 6,
#  'Шипиловская улица': 15,
#  'Шипиловский проезд': 21,
#  'Домодедовская улица': 13,
#  'Ореховый бульвар': 25,
#  'улица Маршала Захарова': 8,
#  'Элеваторная улица': 1,
#  'Товарищеская улица': 1,
#  'Новоспасский проезд': 5,
#  'Новохохловская улица': 6,
#  'Луганская улица': 4,
#  'Полимерная улица': 2,
#  '3-й Павелецкий проезд': 6,
#  'Павелецкая набережная': 3,
#  'Дербеневская набережная': 6,
#  'Кожевническая улица': 9,
#  'Носовихинское шоссе': 6,
#  'Городецкая улица': 8,
#  'Новокосинская улица': 14,
#  'Салтыковская улица': 25,
#  'улица Улофа Пальме': 1,
#  'улица Довженко': 6,
#  'улица Винокурова': 7,
#  'улица Шверника': 4,
#  'улица Гримау': 4,
#  'Менделеевская улица': 3,
#  'улица Богатырский Мост': 3,
#  'Елоховская площадь': 1,
#  '1-й Дербеневский переулок': 2,
#  'улица Маршала Чуйкова': 6,
#  'Михневский проезд': 4,
#  'Никольско-Архангельский проезд': 3,
#  '2-й километр Московской Кольцевой Автодороги': 2,
#  '3-й километр Московской Кольцевой Автодороги': 2,
#  'Задонский проезд': 11,
#  'улица Мусы Джалиля': 15,
#  'Ореховый проезд': 5,
#  'улица Генерала Белова': 14,
#  'Кустанайская улица': 5,
#  'Гурьевский проезд': 8,
#  'Тамбовская улица': 2,
#  'Зеленодольская улица': 4,
#  'улица Маршала Шестопалова': 7,
#  'улица Павла Андреева': 1,
#  'Ключевая улица': 10,
#  'Нижняя Краснохолмская улица': 1,
#  'Даниловская набережная': 4,
#  'Алма-Атинская улица': 2,
#  'улица Галины Вишневской': 1,
#  'Суздальская улица': 16,
#  'улица Строителей': 5,
#  'Юрьевский переулок': 4,
#  'Ухтомская улица': 5,
#  'Нагорный проезд': 6,
#  'улица Шаболовка': 10,
#  'улица Кржижановского': 14,
#  'Большая Черёмушкинская улица': 20,
#  'Загородное шоссе': 14,
#  'улица Вавилова': 23,
#  'улица Орджоникидзе': 4,
#  'Новокузнецкая улица': 6,
#  'Садовнический проезд': 4,
#  'Устьинский проезд': 4,
#  'Яузский бульвар': 1,
#  'Хохловская площадь': 1,
#  'Чистопрудный бульвар': 4,
#  'Покровский бульвар': 3,
#  'Лосиноостровская улица': 16,
#  'Пермская улица': 6,
#  '6-й Лучевой просек': 3,
#  'Белокаменное шоссе': 2,
#  'Яузская аллея': 10,
#  '6-я Радиальная улица': 7,
#  'Пятницкая улица': 5,
#  'улица Большая Ордынка': 6,
#  'Большой Москворецкий мост': 4,
#  '2-й Боткинский проезд': 3,
#  '1-й Боткинский проезд': 2,
#  'улица Матросская Тишина': 9,
#  'Большая Почтовая улица': 8,
#  'Малая Почтовая улица': 3,
#  '1-й Капотнинский проезд': 8,
#  'улица Верхние Поля': 26,
#  'Чагинская улица': 6,
#  'улица Капотня': 13,
#  '14-й километр Московской Кольцевой Автодороги': 2,
#  '11-й километр Московской Кольцевой Автодороги': 3,
#  'улица Цюрупы': 8,
#  'улица Крупской': 4,
#  'улица Свержевского': 2,
#  'Кубанская улица': 1,
#  'Курская улица': 1,
#  '7-я улица Текстильщиков': 1,
#  'Новоцарицынское шоссе': 7,
#  '1-я Радиальная улица': 1,
#  '3-я Радиальная улица': 4,
#  '40-й километр Московской Кольцевой Автодороги': 2,
#  '38-й километр Московской Кольцевой Автодороги': 2,
#  '37-й километр Московской Кольцевой Автодороги': 2,
#  '35-й километр Московской Кольцевой Автодороги': 2,
#  '34-й километр Московской Кольцевой Автодороги': 4,
#  '33-й километр Московской Кольцевой Автодороги': 2,
#  '32-й километр Московской Кольцевой Автодороги': 4,
#  '31-й километр Московской Кольцевой Автодороги': 2,
#  '29-й километр Московской Кольцевой Автодороги': 2,
#  '27-й километр Московской Кольцевой Автодороги': 2,
#  '25-й километр Московской Кольцевой Автодороги': 1,
#  'Шелепихинский мост': 1,
#  '2-я Брестская улица': 2,
#  'улица Тёплый Стан': 14,
#  'проезд Одоевского': 4,
#  'улица Чурилиха': 3,
#  'Малая Тульская улица': 5,
#  'улица Раменки': 4,
#  'улица Кедрова': 4,
#  'Новоостаповская улица': 5,
#  'улица Инессы Арманд': 5,
#  'Тропарёвская улица': 7,
#  '7-я Кожуховская улица': 4,
#  'улица Петра Романова': 1,
#  '6-я Кожуховская улица': 2,
#  'Новомарьинская улица': 12,
#  'улица Ивана Бабушкина': 2,
#  'Соймоновский проезд': 1,
#  'улица Академика Варги': 11,
#  'Рочдельская улица': 4,
#  'улица Генерала Тюленева': 8,
#  '3-я Никопольская улица': 1,
#  'Мелитопольская улица': 1,
#  'проезд Олимпийской Деревни': 3,
#  'улица Рокотова': 3,
#  'Соловьиный проезд': 6,
#  'Боровское шоссе': 66,
#  'Солнцевский проспект': 8,
#  'улица Богданова': 8,
#  '48-й километр Московской Кольцевой Автодороги': 3,
#  'улица Академика Анохина': 16,
#  'улица Академика Бакулева': 6,
#  'Санаторная аллея': 2,
#  'Теплостанский проезд': 1,
#  'Троекуровский проезд': 3,
#  'улица Тюрина': 1,
#  'Попутная улица': 7,
#  'улица 50 лет Октября': 8,
#  'Донбасская улица': 1,
#  'Верхняя Сыромятническая улица': 2,
#  'Гаврикова улица': 2,
#  'Марксистская улица': 10,
#  'бульвар Энтузиастов': 3,
#  'Инициативная улица': 4,
#  'Елизаветинский переулок': 2,
#  '1-й Сыромятнический переулок': 1,
#  '3-й Сыромятнический переулок': 4,
#  '1-я Магистральная улица': 4,
#  '2-я Магистральная улица': 6,
#  'Большая Марфинская улица': 2,
#  'Суворовская площадь': 4,
#  'Артековская улица': 1,
#  '1-й Вешняковский проезд': 2,
#  'улица Приорова': 2,
#  'Пересветов переулок': 1,
#  'улица Головачёва': 2,
#  'улица Комдива Орлова': 4,
#  'площадь Соловецких Юнг': 5,
#  'Совхозная улица': 8,
#  'улица Чистова': 3,
#  'Рузская улица': 1,
#  'Новороссийская улица': 7,
#  'улица Академика Капицы': 3,
#  'Мазиловская улица': 2,
#  'улица Покрышкина': 5,
#  'Домостроительная улица': 5,
#  'Малая Набережная улица': 1,
#  'улица Генерала Дорохова': 11,
#  'Электрозаводский мост': 4,
#  'Пятницкое шоссе': 23,
#  'Дубравная улица': 11,
#  '1-й Митинский переулок': 4,
#  ...}

# %%
sorted(streets.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('3-й Лихачёвский переулок', 1),
#  ('6-й Новоостанкинский проезд', 1),
#  ('улица Кондратюка', 1),
#  ('улица Еланского', 1),
#  ('Гостиничная улица', 1),
#  ('2-й Крестовский переулок', 1),
#  ('улица Черняховского', 1),
#  ('проезд Девичьего Поля', 1),
#  ('улица Маршала Вершинина', 1),
#  ('проезд Стратонавтов', 1),
#  ('5-я Магистральная улица', 1),
#  ('Запорожская улица', 1),
#  ('Житомирская улица', 1),
#  ('Селигерская улица', 1),
#  ('Бескудниковский переулок', 1),
#  ('Полковая улица', 1),
#  ('улица Трёхгорный Вал', 1),
#  ('Стрелецкая улица', 1),
#  ('Павловская улица', 1),
#  ('1-й Ботанический проезд', 1),
#  ('Перуновский переулок', 1),
#  ('1-я Прогонная улица', 1),
#  ('1-я Рыбинская улица', 1),
#  ('8-я улица Соколиной Горы', 1),
#  ('Каширский проезд', 1),
#  ('Сахалинская улица', 1),
#  ('Делегатская улица', 1),
#  ('Спартаковская площадь', 1),
#  ('Кусковский тупик', 1),
#  ('2-я Мякининская улица', 1),
#  ('Подгорская набережная', 1),
#  ('Главная улица', 1),
#  ('4-й Сетуньский проезд', 1),
#  ('2-я Кабельная улица', 1),
#  ('2-й Кабельный проезд', 1),
#  ('Красноворотский проезд', 1),
#  ('улица Полосухина', 1),
#  ('3-я Прядильная улица', 1),
#  ('улица Воронцовские Пруды', 1),
#  ('улица Шухова', 1),
#  ('Устьинская набережная', 1),
#  ('Грузинский переулок', 1),
#  ('Нововоротниковский переулок', 1),
#  ('Элеваторная улица', 1),
#  ('Товарищеская улица', 1),
#  ('улица Улофа Пальме', 1),
#  ('Елоховская площадь', 1),
#  ('улица Павла Андреева', 1),
#  ('Нижняя Краснохолмская улица', 1),
#  ('улица Галины Вишневской', 1),
#  ('Яузский бульвар', 1),
#  ('Хохловская площадь', 1),
#  ('Кубанская улица', 1),
#  ('Курская улица', 1),
#  ('7-я улица Текстильщиков', 1),
#  ('1-я Радиальная улица', 1),
#  ('25-й километр Московской Кольцевой Автодороги', 1),
#  ('Шелепихинский мост', 1),
#  ('улица Петра Романова', 1),
#  ('Соймоновский проезд', 1),
#  ('3-я Никопольская улица', 1),
#  ('Мелитопольская улица', 1),
#  ('Теплостанский проезд', 1),
#  ('улица Тюрина', 1),
#  ('Донбасская улица', 1),
#  ('1-й Сыромятнический переулок', 1),
#  ('Артековская улица', 1),
#  ('Пересветов переулок', 1),
#  ('Рузская улица', 1),
#  ('Малая Набережная улица', 1),
#  ('Муромская улица', 1),
#  ('улица Кухмистерова', 1),
#  ('39-й километр Московской Кольцевой Автодороги', 1),
#  ('Вагоноремонтная улица', 1),
#  ('Северный проезд', 1),
#  ('Гончарная набережная', 1),
#  ('Зоологический переулок', 1),
#  ('Васильевская улица', 1),
#  ('Тишинская площадь', 1),
#  ('улица Подвойского', 1),
#  ('Будайская улица', 1),
#  ('улица Лефортовский Вал', 1),
#  ('улица Адмирала Руднева', 1),
#  ('Крюковская площадь', 1),
#  ('4-й Ходынский проезд', 1),
#  ('Песчаный переулок', 1),
#  ('Измайловская улица', 1),
#  ('Игарский проезд', 1),
#  ('Трудовая аллея', 1),
#  ('Ивовая улица', 1),
#  ('Цариков переулок', 1),
#  ('Новобутовская улица', 1),
#  ('2-я улица Измайловского Зверинца', 1),
#  ('1-я Напрудная улица', 1),
#  ('Графский переулок', 1),
#  ('Воловья улица', 1),
#  ('Красноказарменный проезд', 1),
#  ('Радужный проезд', 1),
#  ('2-я Железнодорожная улица', 1),
#  ('Волоцкой переулок', 1),
#  ('Старокаширское шоссе', 1),
#  ('103-й километр Московской Кольцевой Автодороги', 1),
#  ('2-я Рейсовая улица', 1),
#  ('Бабаевская улица', 1),
#  ('Западная улица', 1),
#  ('улица Берёзки', 1),
#  ('улица Бажова', 1),
#  ('47-й километр Московской Кольцевой Автодороги', 1),
#  ('3-я улица Соколиной Горы', 1),
#  ('Товарищеский переулок', 1),
#  ('Норильская улица', 1),
#  ('улица Дубовой Рощи', 1),
#  ('улица Васильцовский Стан', 1),
#  ('улица Лётчика Ульянина', 1),
#  ('Тихая улица', 1),
#  ('Ивановская улица', 1),
#  ('Госпитальный переулок', 1),
#  ('Береговая улица', 1),
#  ('Чукотский проезд', 1),
#  ('2-й Кожуховский проезд', 1),
#  ('Театральная площадь', 1),
#  ('Рахмановский переулок', 1),
#  ('улица Барышевская Роща', 1),
#  ('1-я Октябрьская улица', 1),
#  ('Новорязанское шоссе', 1),
#  ('улица Маршала Рыбалко', 1),
#  ('улица Коровий Вал', 1),
#  ('площадь Пречистенские Ворота', 1),
#  ('Большая Сухаревская площадь', 1),
#  ('Офицерская улица', 1),
#  ('Безымянный проезд', 1),
#  ('3-й Волоколамский проезд', 1),
#  ('улица Бианки', 1),
#  ('улица Генерала Сандалова', 1),
#  ('2-й Силикатный проезд', 1),
#  ('улица Чёрное Озеро', 1),
#  ('1-й Южнопортовый проезд', 1),
#  ('Сеславинская улица', 1),
#  ('Средняя Калитниковская улица', 1),
#  ('улица Новая Заря', 1),
#  ('улица Правды', 1),
#  ('1-й Лесной переулок', 1),
#  ('Добровольческая улица', 1),
#  ('улица Рудневой', 1),
#  ('улица Липчанского', 1),
#  ('1-й Красногорский проезд', 1),
#  ('Пушкинская площадь', 1),
#  ('Красногвардейский бульвар', 1),
#  ('1-я Боевская улица', 1),
#  ('Беговой проезд', 1),
#  ('Красная улица', 1),
#  ('улица Энгельса', 1),
#  ('Малая Семёновская улица', 1),
#  ('1-й Дорожный проезд', 1),
#  ('Нижняя Первомайская улица', 1),
#  ('12-я Парковая улица', 1),
#  ('11-я Парковая улица', 1),
#  ('Боровицкая площадь', 1),
#  ('улица Охотный Ряд', 1),
#  ('улица Кульнева', 1),
#  ('улица Мустая Карима', 1),
#  ('Малая Юшуньская улица', 1),
#  ('Рязанский проезд', 1),
#  ('улица Матросова', 1),
#  ('Востряковское шоссе', 1),
#  ('Павелецкая площадь', 1),
#  ('1-я Карачаровская улица', 1),
#  ('площадь Московско-Минской Дивизии', 1),
#  ('улица Фёдора Дубовицкого', 1),
#  ('Широкий проезд', 1),
#  ('улица Бочкова', 1),
#  ('3-й проезд Подбельского', 1),
#  ('улица Новая Дорога', 1),
#  ('Гороховский переулок', 1),
#  ('Токмаков переулок', 1),
#  ('Дегунинский проезд', 1),
#  ('Русаковская набережная', 1),
#  ('Есенинский бульвар', 1),
#  ('Пяловская улица', 1),
#  ('Подмосковная улица', 1),
#  ('улица Дениса Давыдова', 1),
#  ('проезд Ольминского', 1),
#  ('улица Маршала Ерёменко', 1),
#  ('1-й Земельный переулок', 1),
#  ('Алымов переулок', 1),
#  ('Стромынский переулок', 1),
#  ('Малая Ботаническая улица', 1),
#  ('Таможенный проезд', 1),
#  ('Средний Золоторожский переулок', 1),
#  ('3-й Дербеневский переулок', 2),
#  ('набережная Тараса Шевченко', 2),
#  ('4-й Лихачёвский переулок', 2),
#  ('Пехотная улица', 2),
#  ('2-й Пехотный переулок', 2),
#  ('Сенежская улица', 2),
#  ('улица Цандера', 2),
#  ('Сусоколовское шоссе', 2),
#  ('Лужнецкий проезд', 2),
#  ('Смоленская-Сенная площадь', 2),
#  ('Кудринская площадь', 2),
#  ('5-я улица Ямского Поля', 2),
#  ('1-я улица Ямского Поля', 2),
#  ('Мякининский проезд', 2),
#  ('Карамышевский проезд', 2),
#  ('улица Амундсена', 2),
#  ('улица Маршала Конева', 2),
#  ('Смоленская площадь', 2),
#  ('площадь Новодевичьего Монастыря', 2),
#  ('Алёшкинский проезд', 2),
#  ('площадь Академика Курчатова', 2),
#  ('Весенняя улица', 2),
#  ('улица Маршала Соколовского', 2),
#  ('Туркменский проезд', 2),
#  ('Гостиничный проезд', 2),
#  ('улица Грачёвка', 2),
#  ('улица Академика Бочвара', 2),
#  ('74-й километр Московской Кольцевой Автодороги', 2),
#  ('Причальный проезд', 2),
#  ('Рубежный проезд', 2),
#  ('Магистральный переулок', 2),
#  ('93-й километр Московской Кольцевой Автодороги', 2),
#  ('91-й километр Московской Кольцевой Автодороги', 2),
#  ('89-й километр Московской Кольцевой Автодороги', 2),
#  ('88-й километр Московской Кольцевой Автодороги', 2),
#  ('87-й километр Московской Кольцевой Автодороги', 2),
#  ('84-й километр Московской Кольцевой Автодороги', 2),
#  ('83-й километр Московской Кольцевой Автодороги', 2),
#  ('Зональная улица', 2),
#  ('Пинский проезд', 2),
#  ('2-й Поперечный проезд', 2),
#  ('улица Боженко', 2),
#  ('Якиманский проезд', 2),
#  ('Береговой проезд', 2),
#  ('улица Санникова', 2),
#  ('Холмогорская улица', 2),
#  ('17-й проезд Марьиной Рощи', 2),
#  ('5-й проезд Марьиной Рощи', 2),
#  ('3-й проезд Марьиной Рощи', 2),
#  ('Подольское шоссе', 2),
#  ('Серпуховская площадь', 2),
#  ('Самотёчная улица', 2),
#  ('Лазоревый проезд', 2),
#  ('2-й Ботанический проезд', 2),
#  ('улица Седова', 2),
#  ('Останкинский проезд', 2),
#  ('1-й Нагатинский проезд', 2),
#  ('Ялтинская улица', 2),
#  ('Оружейный переулок', 2),
#  ('Садовая-Триумфальная улица', 2),
#  ('3-я Мытищинская улица', 2),
#  ('площадь Академика Люльки', 2),
#  ('Спартаковская улица', 2),
#  ('улица Сайкина', 2),
#  ('4-я Гражданская улица', 2),
#  ('Водопроводный переулок', 2),
#  ('Щёлковский проезд', 2),
#  ('Преображенская площадь', 2),
#  ('Вербная улица', 2),
#  ('1-й Варшавский проезд', 2),
#  ('Коломенское шоссе', 2),
#  ('улица Садовники', 2),
#  ('3-я Рыбинская улица', 2),
#  ('улица Лобачика', 2),
#  ('Ольховская улица', 2),
#  ('Малый Купавенский проезд', 2),
#  ('106-й километр Московской Кольцевой Автодороги', 2),
#  ('108-й километр Московской Кольцевой Автодороги', 2),
#  ('5-я улица Соколиной Горы', 2),
#  ('Яснополянская улица', 2),
#  ('Оршанская улица', 2),
#  ('Кунцевская улица', 2),
#  ('улица Екатерины Будановой', 2),
#  ('улица Коцюбинского', 2),
#  ('Никитский бульвар', 2),
#  ('1-й Поперечный проезд', 2),
#  ('Зубовская улица', 2),
#  ('Кремлёвская набережная', 2),
#  ('Пречистенская набережная', 2),
#  ('Нижняя Радищевская улица', 2),
#  ('Андроньевский проезд', 2),
#  ('Душинская улица', 2),
#  ('1-й Сетуньский проезд', 2),
#  ('2-й Сетуньский проезд', 2),
#  ('улица Маросейка', 2),
#  ('улица Семёновский Вал', 2),
#  ('улица Олеко Дундича', 2),
#  ('Измайловская площадь', 2),
#  ('Измайловский проезд', 2),
#  ('1-я Парковая улица', 2),
#  ('Солдатская улица', 2),
#  ('Зеленодольский проезд', 2),
#  ('Лермонтовская площадь', 2),
#  ('Самотёчная площадь', 2),
#  ('Большая Садовая улица', 2),
#  ('Большой Краснохолмский мост', 2),
#  ('Банный переулок', 2),
#  ('Минаевский переулок', 2),
#  ('улица Воейкова', 2),
#  ('улица Михаила Певцова', 2),
#  ('улица Семёнова-Тян-Шанского', 2),
#  ('Смоленская улица', 2),
#  ('проезд Нансена', 2),
#  ('Малая Андроньевская улица', 2),
#  ('площадь Крестьянская Застава', 2),
#  ('Сокольническая площадь', 2),
#  ('Деловая улица', 2),
#  ('Полимерная улица', 2),
#  ('1-й Дербеневский переулок', 2),
#  ('2-й километр Московской Кольцевой Автодороги', 2),
#  ('3-й километр Московской Кольцевой Автодороги', 2),
#  ('Тамбовская улица', 2),
#  ('Алма-Атинская улица', 2),
#  ('Белокаменное шоссе', 2),
#  ('1-й Боткинский проезд', 2),
#  ('14-й километр Московской Кольцевой Автодороги', 2),
#  ('улица Свержевского', 2),
#  ('40-й километр Московской Кольцевой Автодороги', 2),
#  ('38-й километр Московской Кольцевой Автодороги', 2),
#  ('37-й километр Московской Кольцевой Автодороги', 2),
#  ('35-й километр Московской Кольцевой Автодороги', 2),
#  ('33-й километр Московской Кольцевой Автодороги', 2),
#  ('31-й километр Московской Кольцевой Автодороги', 2),
#  ('29-й километр Московской Кольцевой Автодороги', 2),
#  ('27-й километр Московской Кольцевой Автодороги', 2),
#  ('2-я Брестская улица', 2),
#  ('6-я Кожуховская улица', 2),
#  ('улица Ивана Бабушкина', 2),
#  ('Санаторная аллея', 2),
#  ('Верхняя Сыромятническая улица', 2),
#  ('Гаврикова улица', 2),
#  ('Елизаветинский переулок', 2),
#  ('Большая Марфинская улица', 2),
#  ('1-й Вешняковский проезд', 2),
#  ('улица Приорова', 2),
#  ('улица Головачёва', 2),
#  ('Мазиловская улица', 2),
#  ('Лениногорская улица', 2),
#  ('Новоухтомское шоссе', 2),
#  ('44-й километр Московской Кольцевой Автодороги', 2),
#  ('43-й километр Московской Кольцевой Автодороги', 2),
#  ('Старообрядческая улица', 2),
#  ('Подъёмная улица', 2),
#  ('Суздальский проезд', 2),
#  ('улица Рогожский Посёлок', 2),
#  ('Большая Бутовская улица', 2),
#  ('Народная улица', 2),
#  ('67-й километр Московской Кольцевой Автодороги', 2),
#  ('Путилковское шоссе', 2),
#  ('Мелитопольский проезд', 2),
#  ('2-я Мелитопольская улица', 2),
#  ('Дачная улица', 2),
#  ('Котельническая набережная', 2),
#  ('Вересковая улица', 2),
#  ('Новобутовский проезд', 2),
#  ('Ратная улица', 2),
#  ('1-й Миргородский переулок', 2),
#  ('3-я Песчаная улица', 2),
#  ('62-й километр Московской Кольцевой Автодороги', 2),
#  ('66-й километр Московской Кольцевой Автодороги', 2),
#  ('Малая Калитниковская улица', 2),
#  ('Сибирский проезд', 2),
#  ('улица Гиляровского', 2),
#  ('Городская улица', 2),
#  ('Большая Октябрьская улица', 2),
#  ('Спортивная улица', 2),
#  ('Каштановая аллея', 2),
#  ('3-й Угрешский проезд', 2),
#  ('улица Болдов Ручей', 2),
#  ('улица Маршала Шапошникова', 2),
#  ('1-я Фрезерная улица', 2),
#  ('Тарный проезд', 2),
#  ('Трикотажный проезд', 2),
#  ('59-й километр Московской Кольцевой Автодороги', 2),
#  ('улица Арсюкова', 2),
#  ('Каскадная улица', 2),
#  ('улица Академика Флёрова', 2),
#  ('улица Палиха', 2),
#  ('Академическая площадь', 2),
#  ('Некрасовская улица', 2),
#  ('Клинский проезд', 2),
#  ('Новоданиловский проезд', 2),
#  ('1-й Дачно-Мещерский проезд', 2),
#  ('6-й Дачно-Мещерский проезд', 2),
#  ('95-й километр Московской Кольцевой Автодороги', 2),
#  ('Каргопольская улица', 2),
#  ('Ходынский бульвар', 2),
#  ('Витебская улица', 2),
#  ('Тестовская улица', 2),
#  ('Перовский проезд', 2),
#  ('Будайский проезд', 2),
#  ('улица Егора Абакумова', 2),
#  ('Палехская улица', 2),
#  ('Староватутинский проезд', 2),
#  ('Оренбургская улица', 2),
#  ('Верхняя Первомайская улица', 2),
#  ('5-й Загородный проезд', 2),
#  ('Сормовский проезд', 2),
#  ('2-й Тушинский проезд', 2),
#  ('Канатчиковский проезд', 2),
#  ('1-й Краснокурсантский проезд', 2),
#  ('Госпитальная площадь', 2),
#  ('улица Чичерина', 2),
#  ('Лубянский проезд', 2),
#  ('Неглинная улица', 2),
#  ('улица Петровка', 2),
#  ('Скотопрогонная улица', 2),
#  ('улица Панфёрова', 2),
#  ('площадь Сретенские Ворота', 2),
#  ('Ташкентский переулок', 2),
#  ('Писцовая улица', 2),
#  ('Баррикадная улица', 2),
#  ('Житная улица', 2),
#  ('Новодевичий проезд', 2),
#  ('Ростовская набережная', 2),
#  ('улица Дмитрия Рябинкина', 2),
#  ('Милицейский переулок', 2),
#  ('9-й километр Московской Кольцевой Автодороги', 2),
#  ('Комсомольская улица', 2),
#  ('1-я Сестрорецкая улица', 2),
#  ('2-я Подрезковская улица', 2),
#  ('улица Никитина', 2),
#  ('Кировоградский проезд', 2),
#  ('Бекасовская улица', 2),
#  ('Февральская улица', 2),
#  ('Троицкая улица', 2),
#  ('Кленовый бульвар', 2),
#  ('улица Сосенский Стан', 2),
#  ('Мантулинская улица', 2),
#  ('переулок Достоевского', 2),
#  ('переулок Орлово-Давыдовский', 2),
#  ('Петровский бульвар', 2),
#  ('54-й километр Московской Кольцевой Автодороги', 2),
#  ('55-й километр Московской Кольцевой Автодороги', 2),
#  ('49-й километр Московской Кольцевой Автодороги', 2),
#  ('56-й километр Московской Кольцевой Автодороги', 2),
#  ('Власьевская улица', 2),
#  ('1-я Ватутинская улица', 2),
#  ('4-я Ватутинская улица', 2),
#  ('Старопокровский проезд', 2),
#  ('Театральный проезд', 2),
#  ('площадь Славы', 2),
#  ('улица Касаткина', 2),
#  ('Угличская улица', 2),
#  ('16-й километр Московской Кольцевой Автодороги', 2),
#  ('23-й километр Московской Кольцевой Автодороги', 2),
#  ('21-й километр Московской Кольцевой Автодороги', 2),
#  ('20-й километр Московской Кольцевой Автодороги', 2),
#  ('улица Тренёва', 2),
#  ('улица Академика Христиановича', 2),
#  ('2-й Южнопортовый проезд', 2),
#  ('2-я Фрунзенская улица', 2),
#  ('Верхнелихоборская улица', 2),
#  ('Халтуринский проезд', 2),
#  ('Народный проспект', 2),
#  ('улица Академика Виноградова', 2),
#  ('Прудовая улица', 2),
#  ('улица Годовикова', 2),
#  ('Аргуновская улица', 2),
#  ('1-й Новоподмосковный переулок', 2),
#  ('Борисовская улица', 2),
#  ('Остаповский проезд', 2),
#  ('улица Ляпидевского', 2),
#  ('улица Казакова', 2),
#  ('7-й километр Московской Кольцевой Автодороги', 2),
#  ('улица Богородский Вал', 2),
#  ('Маленковская улица', 2),
#  ('улица Сокольническая Слободка', 2),
#  ('7-я улица Лазенки', 2),
#  ('Верхняя улица', 2),
#  ('5-я Нововатутинская улица', 2),
#  ('улица Недорубова', 2),
#  ('Физкультурный проезд', 2),
#  ('Долгопрудная улица', 2),
#  ('3-я Гражданская улица', 2),
#  ('улица Барболина', 2),
#  ('70-й километр Московской Кольцевой Автодороги', 2),
#  ('проезд Черепановых', 2),
#  ('Авиамоторный проезд', 2),
#  ('6-я улица Лазенки', 2),
#  ('Сосновая улица', 3),
#  ('2-я Хуторская улица', 3),
#  ('улица Лужники', 3),
#  ('Лужнецкая набережная', 3),
#  ('улица Саляма Адиля', 3),
#  ('Песчаная площадь', 3),
#  ('Минусинская улица', 3),
#  ('проезд Соломенной Сторожки', 3),
#  ('улица Максимова', 3),
#  ('Одинцовская улица', 3),
#  ('Ижорский проезд', 3),
#  ('улица Сергея Эйзенштейна', 3),
#  ('Отрадный проезд', 3),
#  ('Мелиховская улица', 3),
#  ('Псковская улица', 3),
#  ('Вяземская улица', 3),
#  ('улица Кубинка', 3),
#  ('Гвардейская улица', 3),
#  ('Староможайское шоссе', 3),
#  ('улица Серафимовича', 3),
#  ('Истринская улица', 3),
#  ('Заревый проезд', 3),
#  ('2-й Красногвардейский проезд', 3),
#  ('Мясницкая улица', 3),
#  ('Селезнёвская улица', 3),
#  ('улица Намёткина', 3),
#  ('Страстной бульвар', 3),
#  ('Семёновская площадь', 3),
#  ('Игральная улица', 3),
#  ('Велозаводская улица', 3),
#  ('улица Мастеркова', 3),
#  ('2-й Полевой переулок', 3),
#  ('2-й Котляковский переулок', 3),
#  ('улица Достоевского', 3),
#  ('Иркутская улица', 3),
#  ('Снайперская улица', 3),
#  ('улица Уткина', 3),
#  ('улица Паперника', 3),
#  ('Полоцкая улица', 3),
#  ('Обводное шоссе', 3),
#  ('улица Вострухина', 3),
#  ('Таганская площадь', 3),
#  ('Верхняя Радищевская улица', 3),
#  ('улица Александра Солженицына', 3),
#  ('Жигулёвская улица', 3),
#  ('13-я Парковая улица', 3),
#  ('Абельмановская улица', 3),
#  ('Садовая-Черногрязская улица', 3),
#  ('Малая Сухаревская площадь', 3),
#  ('улица Крымский Вал', 3),
#  ('Валовая улица', 3),
#  ('улица Академика Челомея', 3),
#  ('улица Кошкина', 3),
#  ('Павелецкая набережная', 3),
#  ('Менделеевская улица', 3),
#  ('улица Богатырский Мост', 3),
#  ('Никольско-Архангельский проезд', 3),
#  ('Покровский бульвар', 3),
#  ('6-й Лучевой просек', 3),
#  ('2-й Боткинский проезд', 3),
#  ('Малая Почтовая улица', 3),
#  ('11-й километр Московской Кольцевой Автодороги', 3),
#  ('улица Чурилиха', 3),
#  ('проезд Олимпийской Деревни', 3),
#  ('улица Рокотова', 3),
#  ('48-й километр Московской Кольцевой Автодороги', 3),
#  ('Троекуровский проезд', 3),
#  ('бульвар Энтузиастов', 3),
#  ('улица Чистова', 3),
#  ('улица Академика Капицы', 3),
#  ('улица Главмосстроя', 3),
#  ('Поселковая улица', 3),
#  ('10-я улица Соколиной Горы', 3),
#  ('улица Михельсона', 3),
#  ('улица Солянка', 3),
#  ('Вокзальная площадь', 3),
#  ('1-я Вольская улица', 3),
#  ('1-я Рейсовая улица', 3),
#  ('Куркинское шоссе', 3),
#  ('улица Николая Коперника', 3),
#  ('улица Соловьиная Роща', 3),
#  ('1-й Магистральный тупик', 3),
#  ('улица Академика Опарина', 3),
#  ('Малыгинский проезд', 3),
#  ('проезд Берёзовой Рощи', 3),
#  ('Маломосковская улица', 3),
#  ('улица Кадырова', 3),
#  ('проезд № 4807', 3),
#  ('проезд № 4921', 3),
#  ('улица Академика Понтрягина', 3),
#  ('улица Наташи Качуевской', 3),
#  ('Тушинская улица', 3),
#  ('9-я улица Соколиной Горы', 3),
#  ('проезд Завода Серп и Молот', 3),
#  ('улица Маргелова', 3),
#  ('Школьная улица', 3),
#  ('Армейская улица', 3),
#  ('Физическая улица', 3),
#  ('Учительская улица', 3),
#  ('улица Варварка', 3),
#  ('Нововатутинский проспект', 3),
#  ('Насосная улица', 3),
#  ('1-й Войковский проезд', 3),
#  ('5-й Войковский проезд', 3),
#  ('Балтийская улица', 3),
#  ('Пресненская набережная', 3),
#  ('Винницкая улица', 3),
#  ('4-й Загородный проезд', 3),
#  ('Иваньковское шоссе', 3),
#  ('2-й Красковский проезд', 3),
#  ('улица Полковника Милиции Курочкина', 3),
#  ('4-й Рощинский проезд', 3),
#  ('1-й Рощинский проезд', 3),
#  ('Фитарёвская улица', 3),
#  ('улица Каретный Ряд', 3),
#  ('Главная аллея', 3),
#  ('бульвар Генерала Карбышева', 3),
#  ('улица Воздвиженка', 3),
#  ('Моховая улица', 3),
#  ('улица Камова', 3),
#  ('улица Доктора Гааза', 3),
#  ('Мироновская улица', 3),
#  ('Научный проезд', 3),
#  ('Космодамианская набережная', 3),
#  ('Коптевский бульвар', 4),
#  ('4-й Новомихалковский проезд', 4),
#  ('1-й Волоколамский проезд', 4),
#  ('улица Усиевича', 4),
#  ('Часовая улица', 4),
#  ('улица Прянишникова', 4),
#  ('улица Бусиновская Горка', 4),
#  ('Новинский бульвар', 4),
#  ('Смоленский бульвар', 4),
#  ('Светлогорский проезд', 4),
#  ('улица Расковой', 4),
#  ('3-й Нижнелихоборский проезд', 4),
#  ('Рижская площадь', 4),
#  ('Старый Петровско-Разумовский проезд', 4),
#  ('Строительный проезд', 4),
#  ('Вишнёвая улица', 4),
#  ('Песчаная улица', 4),
#  ('Талдомская улица', 4),
#  ('Керамический проезд', 4),
#  ('улица Паршина', 4),
#  ('Шелепихинское шоссе', 4),
#  ('Отрадная улица', 4),
#  ('Шелепихинская набережная', 4),
#  ('улица Фомичёвой', 4),
#  ('92-й километр Московской Кольцевой Автодороги', 4),
#  ('улица Толбухина', 4),
#  ('Кременчугская улица', 4),
#  ('Воробьёвское шоссе', 4),
#  ('Новофилёвский проезд', 4),
#  ('Молдавская улица', 4),
#  ('улица Пестеля', 4),
#  ('Россошанский проезд', 4),
#  ('Россошанская улица', 4),
#  ('улица Гончарова', 4),
#  ('улица Двинцев', 4),
#  ('улица Грузинский Вал', 4),
#  ('Новый Берингов проезд', 4),
#  ('улица Сергея Макеева', 4),
#  ('Харьковская улица', 4),
#  ('улица Добролюбова', 4),
#  ('Большая Переяславская улица', 4),
#  ('улица Образцова', 4),
#  ('улица Новая Башиловка', 4),
#  ('Новоалексеевская улица', 4),
#  ('улица Преображенский Вал', 4),
#  ('улица Олений Вал', 4),
#  ('Большая Ширяевская улица', 4),
#  ('Миллионная улица', 4),
#  ('Вельяминовская улица', 4),
#  ('Халтуринская улица', 4),
#  ('Просторная улица', 4),
#  ('улица Ленинская Слобода', 4),
#  ('Преображенская улица', 4),
#  ('улица Бориса Жигулёнкова', 4),
#  ('улица Шумкина', 4),
#  ('Курганская улица', 4),
#  ('Чусовская улица', 4),
#  ('Одесская улица', 4),
#  ('улица Старый Гай', 4),
#  ('Напольный проезд', 4),
#  ('Электролитный проезд', 4),
#  ('Ясногорская улица', 4),
#  ('улица Айвазовского', 4),
#  ('улица Коновалова', 4),
#  ('Кузьминская улица', 4),
#  ('улица Зацепский Вал', 4),
#  ('Сормовская улица', 4),
#  ('Яузская улица', 4),
#  ('проезд Стройкомбината', 4),
#  ('Керченская улица', 4),
#  ('улица Шкулёва', 4),
#  ('Багратионовский проезд', 4),
#  ('Большая Андроньевская улица', 4),
#  ('Садовая-Спасская улица', 4),
#  ('Садовая-Самотёчная улица', 4),
#  ('Зубовский бульвар', 4),
#  ('улица Пржевальского', 4),
#  ('Новосущёвский переулок', 4),
#  ('улица Николая Химушина', 4),
#  ('Вильнюсская улица', 4),
#  ('улица Академика Хохлова', 4),
#  ('улица Паустовского', 4),
#  ('Конюшковская улица', 4),
#  ('улица Даниловский Вал', 4),
#  ('Ряжская улица', 4),
#  ('Луганская улица', 4),
#  ('улица Шверника', 4),
#  ('улица Гримау', 4),
#  ('Михневский проезд', 4),
#  ('Зеленодольская улица', 4),
#  ('Даниловская набережная', 4),
#  ('Юрьевский переулок', 4),
#  ('улица Орджоникидзе', 4),
#  ('Садовнический проезд', 4),
#  ('Устьинский проезд', 4),
#  ('Чистопрудный бульвар', 4),
#  ('Большой Москворецкий мост', 4),
#  ('улица Крупской', 4),
#  ('3-я Радиальная улица', 4),
#  ('34-й километр Московской Кольцевой Автодороги', 4),
#  ('32-й километр Московской Кольцевой Автодороги', 4),
#  ('проезд Одоевского', 4),
#  ('улица Раменки', 4),
#  ('улица Кедрова', 4),
#  ('7-я Кожуховская улица', 4),
#  ('Рочдельская улица', 4),
#  ('Инициативная улица', 4),
#  ('3-й Сыромятнический переулок', 4),
#  ('1-я Магистральная улица', 4),
#  ('Суворовская площадь', 4),
#  ('улица Комдива Орлова', 4),
#  ('Электрозаводский мост', 4),
#  ('1-й Митинский переулок', 4),
#  ('улица Академика Глушко', 4),
#  ('улица Знаменские Садки', 4),
#  ('Волынская улица', 4),
#  ('9-я Чоботовская аллея', 4),
#  ('Саранская улица', 4),
#  ('Лермонтовский проспект', 4),
#  ('Хвалынский бульвар', 4),
#  ('бульвар Адмирала Ушакова', 4),
#  ('улица Зарянова', 4),
#  ('Родионовская улица', 4),
#  ('Вятская улица', 4),
#  ('улица Академика Полякова', 4),
#  ('Цимлянская улица', 4),
#  ('улица Саломеи Нерис', 4),
#  ('1-й Котляковский переулок', 4),
#  ('улица Текстильщиков', 4),
#  ('Никулинский проезд', 4),
#  ('Комсомольская площадь', 4),
#  ('Середниковская улица', 4),
#  ('проезд № 474', 4),
#  ('улица Татьяны Макаровой', 4),
#  ('улица Панфилова', 4),
#  ('улица Бориса Петровского', 4),
#  ('9-я Северная линия', 4),
#  ('Новотушинский проезд', 4),
#  ('улица Маршала Прошлякова', 4),
#  ('Новодачное шоссе', 4),
#  ('улица Атласова', 4),
#  ('Мурманский проезд', 4),
#  ('улица Юлиана Семёнова', 4),
#  ('улица Липовый Парк', 4),
#  ('Смирновская улица', 4),
#  ('улица Лётчика Грицевца', 4),
#  ('Луховицкая улица', 4),
#  ('Энергетическая улица', 4),
#  ('улица Речников', 4),
#  ('Ягодная улица', 4),
#  ('Бутовский тупик', 4),
#  ('улица Анны Ахматовой', 4),
#  ('Николо-Хованская улица', 4),
#  ('улица Героя России Соломатина', 4),
#  ('улица Сретенка', 4),
#  ('площадь Тверская Застава', 4),
#  ('Садовая-Каретная улица', 4),
#  ('Смоленская набережная', 4),
#  ('Батюнинский проезд', 4),
#  ('Базовская улица', 4),
#  ('улица Вертолётчиков', 4),
#  ('улица Госпитальный Вал', 4),
#  ('Новоданиловская набережная', 4),
#  ('улица Космонавтов', 4),
#  ('улица Малая Дмитровка', 4),
#  ('улица Волхонка', 4),
#  ('18-й километр Московской Кольцевой Автодороги', 4),
#  ('улица Погодина', 4),
#  ('проспект Лихачёва', 4),
#  ('улица Пруд-Ключики', 4),
#  ('Дмитровский проезд', 4),
#  ('Лечебная улица', 4),
#  ('Потешная улица', 4),
#  ('улица Самуила Маршака', 4),
#  ('Федоскинская улица', 4),
#  ('3-я Черепковская улица', 5),
#  ('Путейская улица', 5),
#  ('улица Клары Цеткин', 5),
#  ('Нарвская улица', 5),
#  ('улица Академика Курчатова', 5),
#  ('Краснополянская улица', 5),
#  ('улица Лавочкина', 5),
#  ('Звёздный бульвар', 5),
#  ('Красностуденческий проезд', 5),
#  ('улица Расплетина', 5),
#  ('2-я Квесисская улица', 5),
#  ('4-й Вятский переулок', 5),
#  ('улица Рогова', 5),
#  ('улица Маршала Новикова', 5),
#  ('3-я Магистральная улица', 5),
#  ('улица Вильгельма Пика', 5),
#  ('Олонецкая улица', 5),
#  ('2-й Хорошёвский проезд', 5),
#  ('Лианозовский проезд', 5),
#  ('улица Артамонова', 5),
#  ('Сумская улица', 5),
#  ('Вологодский проезд', 5),
#  ('улица Большая Якиманка', 5),
#  ('улица Мусоргского', 5),
#  ('Мирской переулок', 5),
#  ('улица Фонвизина', 5),
#  ('Печорская улица', 5),
#  ('улица Дурова', 5),
#  ('Ростокинская улица', 5),
#  ('улица Новинки', 5),
#  ('Щербаковская улица', 5),
#  ('улица Измайловский Вал', 5),
#  ('Большая Оленья улица', 5),
#  ('Затонная улица', 5),
#  ('Якорная улица', 5),
#  ('Котляковская улица', 5),
#  ('улица Сергия Радонежского', 5),
#  ('Новорогожская улица', 5),
#  ('Камчатская улица', 5),
#  ('3-й Самотёчный переулок', 5),
#  ('2-й Иртышский проезд', 5),
#  ('Электродная улица', 5),
#  ('улица Металлургов', 5),
#  ('улица Лазо', 5),
#  ('улица Ремизова', 5),
#  ('Тарусская улица', 5),
#  ('улица Василия Ботылёва', 5),
#  ('Бобруйская улица', 5),
#  ('7-я Парковая улица', 5),
#  ('улица Судакова', 5),
#  ('Тихорецкий бульвар', 5),
#  ('Лубянская площадь', 5),
#  ('улица Марии Ульяновой', 5),
#  ('улица Лебедева', 5),
#  ('Сущёвская улица', 5),
#  ('Паромная улица', 5),
#  ('Елецкая улица', 5),
#  ('Касимовская улица', 5),
#  ('Загорьевская улица', 5),
#  ('Новоспасский проезд', 5),
#  ('Ореховый проезд', 5),
#  ('Кустанайская улица', 5),
#  ('улица Строителей', 5),
#  ('Ухтомская улица', 5),
#  ('Пятницкая улица', 5),
#  ('Малая Тульская улица', 5),
#  ('Новоостаповская улица', 5),
#  ('улица Инессы Арманд', 5),
#  ('площадь Соловецких Юнг', 5),
#  ('улица Покрышкина', 5),
#  ('Домостроительная улица', 5),
#  ('Бесединское шоссе', 5),
#  ('улица Щорса', 5),
#  ('Новопеределкинская улица', 5),
#  ('Новоорловская улица', 5),
#  ('Луговой проезд', 5),
#  ('Красковская улица', 5),
#  ('Тихвинская улица', 5),
#  ('улица Проходчиков', 5),
#  ('улица Саморы Машела', 5),
#  ('Воротынская улица', 5),
#  ('улица Талалихина', 5),
#  ('улица Авиаконструктора Микояна', 5),
#  ('1-я Мясниковская улица', 5),
#  ('1-й Красногвардейский проезд', 5),
#  ('улица Михайловка', 5),
#  ('улица Конструктора Гуськова', 5),
#  ('улица Александровка', 5),
#  ('Малинская улица', 5),
#  ('Заводское шоссе', 5),
#  ('улица Лётчицы Тарасовой', 5),
#  ('улица Академика Алиханова', 5),
#  ('улица Рословка', 5),
#  ('улица Харлампиева', 5),
#  ('Рождественская улица', 5),
#  ('Клинская улица', 5),
#  ('1-й Пенягинский проезд', 5),
#  ('Озёрная аллея', 5),
#  ('улица Кибальчича', 5),
#  ('Раменский бульвар', 5),
#  ('Госпитальная улица', 5),
#  ('набережная Новикова-Прибоя', 5),
#  ('улица Корнея Чуковского', 5),
#  ('улица Маресьева', 5),
#  ('Новостроевская улица', 5),
#  ('улица Татьянин Парк', 5),
#  ('улица Ротерта', 5),
#  ('Цветной бульвар', 5),
#  ('2-я Бауманская улица', 5),
#  ('площадь Савёловского Вокзала', 5),
#  ('улица Лавриненко', 5),
#  ('улица Пырьева', 5),
#  ('улица Золоторожский Вал', 5),
#  ('улица Линии Октябрьской Железной Дороги', 6),
#  ('Автомоторная улица', 6),
#  ('Петровско-Разумовская аллея', 6),
#  ('Авангардная улица', 6),
#  ('Солнечногорская улица', 6),
#  ('улица Вучетича', 6),
#  ('Ижорская улица', 6),
#  ('улица Маршала Федоренко', 6),
#  ('улица Хамовнический Вал', 6),
#  ('улица 1905 Года', 6),
#  ('Химкинский бульвар', 6),
#  ('улица Маршала Василевского', 6),
#  ('улица Генерала Глаголева', 6),
#  ('Ростокинский проезд', 6),
#  ('Строгинское шоссе', 6),
#  ('улица Гамалеи', 6),
#  ('4-я Магистральная улица', 6),
#  ('Мурановская улица', 6),
#  ('Илимская улица', 6),
#  ('улица Говорова', 6),
#  ('Северодвинская улица', 6),
#  ('Тайнинская улица', 6),
#  ('Инженерная улица', 6),
#  ('Челюскинская улица', 6),
#  ('улица Академика Янгеля', 6),
#  ('Станционная улица', 6),
#  ('Кольская улица', 6),
#  ('улица Советской Армии', 6),
#  ('Краснопролетарская улица', 6),
#  ('Долгоруковская улица', 6),
#  ('Стрельбищенский переулок', 6),
#  ('Новорязанская улица', 6),
#  ('Большая Семёновская улица', 6),
#  ('Битцевский проезд', 6),
#  ('улица Большие Каменщики', 6),
#  ('улица Газопровод', 6),
#  ('Костомаровский переулок', 6),
#  ('Уссурийская улица', 6),
#  ('Красноярская улица', 6),
#  ('Фрязевская улица', 6),
#  ('Мартеновская улица', 6),
#  ('улица Плющева', 6),
#  ('Вольная улица', 6),
#  ('Измайловское шоссе', 6),
#  ('аллея Жемчуговой', 6),
#  ('Таганская улица', 6),
#  ('улица Маршала Тимошенко', 6),
#  ('1-я улица Машиностроения', 6),
#  ('Гоголевский бульвар', 6),
#  ('Москворецкая набережная', 6),
#  ('Воронцовская улица', 6),
#  ('Славянская площадь', 6),
#  ('Очаковское шоссе', 6),
#  ('Староволынская улица', 6),
#  ('Тверской бульвар', 6),
#  ('улица Остоженка', 6),
#  ('Подольская улица', 6),
#  ('Саратовская улица', 6),
#  ('Доброслободская улица', 6),
#  ('Никитинская улица', 6),
#  ('улица Рогожский Вал', 6),
#  ('Садовая-Кудринская улица', 6),
#  ('Большая Грузинская улица', 6),
#  ('Малая Грузинская улица', 6),
#  ('Хордовый проезд', 6),
#  ('Холодильный переулок', 6),
#  ('Иловайская улица', 6),
#  ('улица Медиков', 6),
#  ('Новохохловская улица', 6),
#  ('3-й Павелецкий проезд', 6),
#  ('Дербеневская набережная', 6),
#  ('Носовихинское шоссе', 6),
#  ('улица Довженко', 6),
#  ('улица Маршала Чуйкова', 6),
#  ('Нагорный проезд', 6),
#  ('Новокузнецкая улица', 6),
#  ('Пермская улица', 6),
#  ('улица Большая Ордынка', 6),
#  ('Чагинская улица', 6),
#  ('Соловьиный проезд', 6),
#  ('улица Академика Бакулева', 6),
#  ('2-я Магистральная улица', 6),
#  ('Старокачаловская улица', 6),
#  ('Производственная улица', 6),
#  ('Коктебельская улица', 6),
#  ('Чоботовская улица', 6),
#  ('Златоустовская улица', 6),
#  ('Международное шоссе', 6),
#  ('Остафьевская улица', 6),
#  ('Заповедная улица', 6),
#  ('Нижняя Красносельская улица', 6),
#  ('Большая Юшуньская улица', 6),
#  ('Юровская улица', 6),
#  ('Левобережная улица', 6),
#  ('улица Маршала Воробьёва', 6),
#  ('улица Гризодубовой', 6),
#  ('Солнечная аллея', 6),
#  ('улица Гоголя', 6),
#  ('Филаретовская улица', 6),
#  ('Островная улица', 6),
#  ('Вернисажная улица', 6),
#  ('Сухонская улица', 6),
#  ('Яковлевская улица', 6),
#  ('улица 40 лет Октября', 6),
#  ('Бачуринская улица', 6),
#  ('Автомобильный проезд', 6),
#  ('улица Зорге', 6),
#  ('Саввинская набережная', 6),
#  ('площадь Киевского Вокзала', 6),
#  ...]
