# %% [markdown]
# # Введение в Jupyter

# %% [markdown]
# Что мы будем сегодня делать?
#
# * Разбееремся с типами ячеек
# * Поработаем с данными в формате .csv

# %%
import csv

# %%
streets = {}

# %%
# %time
with open('bus_stops.csv', 'r', encoding='cp1251') as f:
    reader = csv.DictReader(f, delimiter=';')
    for row in reader:
        if row['Street'] in streets:
            streets[row['Street']] += 1
        else:
            streets[row['Street']] = 1
# Out:
# Wall time: 0 ns

# %%
streets
# Out:
# {'3-й Дербеневский переулок': 6,
#  'набережная Тараса Шевченко': 6,
#  '3-я Черепковская улица': 15,
#  'улица Сущёвский Вал': 48,
#  'Дубнинская улица': 87,
#  'улица 800-летия Москвы': 39,
#  'Дмитровское шоссе': 207,
#  'Локомотивный проезд': 21,
#  'Большая Академическая улица': 75,
#  'улица Зои и Александра Космодемьянских': 42,
#  'Путейская улица': 15,
#  'Ангарская улица': 42,
#  'Коровинское шоссе': 72,
#  'Клязьминская улица': 36,
#  'улица Линии Октябрьской Железной Дороги': 18,
#  'Старопетровский проезд': 24,
#  'улица Клары Цеткин': 15,
#  'Михалковская улица': 45,
#  'Онежская улица': 33,
#  'Петрозаводская улица': 24,
#  'Беломорская улица': 30,
#  'Смольная улица': 51,
#  'Фестивальная улица': 72,
#  'Бескудниковский бульвар': 63,
#  'Коптевский бульвар': 12,
#  'Коптевская улица': 33,
#  'Кронштадтский бульвар': 63,
#  'Нарвская улица': 15,
#  '3-й Лихачёвский переулок': 3,
#  '4-й Лихачёвский переулок': 6,
#  'Автомоторная улица': 18,
#  '4-й Новомихалковский проезд': 12,
#  'Митинская улица': 42,
#  'улица Дыбенко': 30,
#  'Зеленоградская улица': 42,
#  'улица Академика Курчатова': 15,
#  'Сосновая улица': 9,
#  'Пехотная улица': 6,
#  '1-й Волоколамский проезд': 12,
#  'улица Усиевича': 12,
#  'Планетная улица': 21,
#  'Петровско-Разумовская аллея': 18,
#  'Часовая улица': 12,
#  '2-й Пехотный переулок': 6,
#  'Авангардная улица': 18,
#  'Флотская улица': 39,
#  'Солнечногорская улица': 18,
#  'Сенежская улица': 6,
#  'улица Прянишникова': 12,
#  'Тимирязевская улица': 63,
#  'улица Вучетича': 18,
#  '2-я Хуторская улица': 9,
#  'Петровско-Разумовский проезд': 24,
#  'Ижорская улица': 18,
#  'улица Бусиновская Горка': 12,
#  'Краснополянская улица': 15,
#  'улица Лавочкина': 15,
#  'Бутырская улица': 48,
#  'улица Бутырский Вал': 24,
#  'Новослободская улица': 24,
#  'Херсонская улица': 30,
#  'Волоколамское шоссе': 138,
#  'Ленинградский проспект': 105,
#  'Ботаническая улица': 42,
#  'улица Академика Королёва': 51,
#  'Новомосковская улица': 21,
#  'Звёздный бульвар': 15,
#  '6-й Новоостанкинский проезд': 3,
#  'улица Цандера': 6,
#  'улица Кондратюка': 3,
#  'проспект Мира': 219,
#  'Сусоколовское шоссе': 6,
#  'улица Свободы': 102,
#  'Сходненская улица': 36,
#  'улица Маршала Федоренко': 18,
#  'улица Лужники': 9,
#  'Лужнецкая набережная': 9,
#  'Лужнецкий проезд': 6,
#  'Большая Пироговская улица': 36,
#  'улица Плющиха': 24,
#  'улица Хамовнический Вал': 18,
#  'Смоленская-Сенная площадь': 6,
#  'Новинский бульвар': 12,
#  'улица Красная Пресня': 24,
#  'улица 1905 Года': 18,
#  'Хорошёвское шоссе': 63,
#  'Кудринская площадь': 6,
#  'улица Еланского': 3,
#  'Красностуденческий проезд': 15,
#  'Смоленский бульвар': 12,
#  'улица Берзарина': 36,
#  'улица Расплетина': 15,
#  'улица Маршала Бирюзова': 48,
#  'улица Василия Петушкова': 33,
#  'Светлогорский проезд': 12,
#  'улица Героев Панфиловцев': 111,
#  'Гостиничная улица': 3,
#  'Башиловская улица': 24,
#  'улица Расковой': 12,
#  '5-я улица Ямского Поля': 6,
#  '1-я улица Ямского Поля': 6,
#  'улица Нижняя Масловка': 24,
#  '3-й Нижнелихоборский проезд': 12,
#  'улица Исаковского': 42,
#  'улица Маршала Катукова': 48,
#  'Рублёвское шоссе': 120,
#  'улица Кулакова': 51,
#  '2-я Квесисская улица': 15,
#  'Мякининский проезд': 6,
#  '2-й Крестовский переулок': 3,
#  'Рижская площадь': 12,
#  '4-й Вятский переулок': 15,
#  'Старый Петровско-Разумовский проезд': 12,
#  'бульвар Яна Райниса': 51,
#  'Химкинский бульвар': 18,
#  'улица Куусинена': 33,
#  'улица Маршала Тухачевского': 33,
#  'улица Народного Ополчения': 72,
#  'улица Саляма Адиля': 9,
#  'Карамышевская набережная': 33,
#  'улица Мнёвники': 27,
#  'проспект Маршала Жукова': 69,
#  'Таманская улица': 42,
#  'Карамышевский проезд': 6,
#  'Звенигородское шоссе': 27,
#  'Песчаная площадь': 9,
#  'Новопесчаная улица': 24,
#  'Ленинградское шоссе': 171,
#  'Анадырский проезд': 30,
#  'улица Малыгина': 27,
#  'Изумрудная улица': 30,
#  'Минусинская улица': 9,
#  'улица Коминтерна': 33,
#  'Радужная улица': 30,
#  'Енисейская улица': 66,
#  'проезд Серебрякова': 30,
#  'улица Амундсена': 6,
#  'Туристская улица': 30,
#  'Походный проезд': 21,
#  'Строительный проезд': 12,
#  'проезд Донелайтиса': 24,
#  'улица Фабрициуса': 30,
#  'Лодочная улица': 33,
#  'Вишнёвая улица': 12,
#  'улица Генерала Белобородова': 48,
#  'улица Маршала Конева': 6,
#  'улица Алабяна': 21,
#  'улица Черняховского': 3,
#  'улица Маршала Василевского': 18,
#  'Песчаная улица': 12,
#  'проезд Девичьего Поля': 3,
#  'Смоленская площадь': 6,
#  'площадь Новодевичьего Монастыря': 6,
#  'Ельнинская улица': 24,
#  'проезд без названия': 1857,
#  'улица Генерала Глаголева': 18,
#  'Планерная улица': 39,
#  'Снежная улица': 27,
#  'проезд Соломенной Сторожки': 9,
#  'Алёшкинский проезд': 6,
#  'улица Корнейчука': 45,
#  'улица Лескова': 54,
#  'Широкая улица': 69,
#  'улица Бориса Галушкина': 27,
#  'Ростокинский проезд': 18,
#  'Богородское шоссе': 24,
#  'улица Максимова': 9,
#  'улица Рогова': 15,
#  'площадь Академика Курчатова': 6,
#  'Талдомская улица': 12,
#  'Керамический проезд': 12,
#  'Весенняя улица': 6,
#  'Лобненская улица': 27,
#  'Живописная улица': 48,
#  'улица Паршина': 12,
#  'улица Маршала Соколовского': 6,
#  'улица Маршала Новикова': 15,
#  'Авиационная улица': 45,
#  'улица Маршала Вершинина': 3,
#  'улица Твардовского': 33,
#  'Таллинская улица': 54,
#  'Новощукинская улица': 39,
#  'проезд Стратонавтов': 3,
#  'Строгинское шоссе': 18,
#  'Тушинская площадь': 24,
#  'Туркменский проезд': 6,
#  'Одинцовская улица': 9,
#  'Строгинский бульвар': 27,
#  'Ижорский проезд': 9,
#  'Прибрежный проезд': 24,
#  'Неманский проезд': 24,
#  'Гостиничный проезд': 6,
#  'улица Космонавта Волкова': 21,
#  'улица Грачёвка': 6,
#  'улица Академика Бочвара': 6,
#  'улица Гамалеи': 18,
#  'Карельский бульвар': 21,
#  'улица Софьи Ковалевской': 27,
#  '74-й километр Московской Кольцевой Автодороги': 6,
#  '1-й Силикатный проезд': 24,
#  'Шелепихинское шоссе': 12,
#  '3-я Магистральная улица': 15,
#  '4-я Магистральная улица': 18,
#  'улица Нижние Мнёвники': 36,
#  'улица Сергея Эйзенштейна': 9,
#  'улица Вильгельма Пика': 15,
#  'Берёзовая аллея': 27,
#  'Олонецкая улица': 15,
#  'Отрадная улица': 12,
#  'Отрадный проезд': 9,
#  'Сигнальный проезд': 27,
#  'Продольный проезд': 45,
#  'улица Вилиса Лациса': 39,
#  'Причальный проезд': 6,
#  'Шелепихинская набережная': 12,
#  'Большая Филёвская улица': 48,
#  'Минская улица': 45,
#  'улица Фомичёвой': 12,
#  'Осенний бульвар': 30,
#  'улица Крылатские Холмы': 51,
#  'Рубежный проезд': 6,
#  'Беговая улица': 21,
#  'Магистральный переулок': 6,
#  '2-й Хорошёвский проезд': 15,
#  '5-я Магистральная улица': 3,
#  'улица Заморёнова': 21,
#  '3-я Хорошёвская улица': 30,
#  'Ярославское шоссе': 72,
#  '93-й километр Московской Кольцевой Автодороги': 6,
#  '92-й километр Московской Кольцевой Автодороги': 12,
#  '91-й километр Московской Кольцевой Автодороги': 6,
#  '89-й километр Московской Кольцевой Автодороги': 6,
#  '88-й километр Московской Кольцевой Автодороги': 6,
#  '87-й километр Московской Кольцевой Автодороги': 6,
#  '84-й километр Московской Кольцевой Автодороги': 6,
#  '83-й километр Московской Кольцевой Автодороги': 6,
#  'Лианозовский проезд': 15,
#  'Мелиховская улица': 9,
#  'Белозерская улица': 21,
#  'Мурановская улица': 18,
#  'улица Пришвина': 27,
#  'Бибиревская улица': 33,
#  'Алтуфьевское шоссе': 141,
#  'Костромская улица': 24,
#  'Череповецкая улица': 48,
#  'улица Ивана Сусанина': 21,
#  'Осенняя улица': 24,
#  'Крылатская улица': 60,
#  'Осташковская улица': 30,
#  'Псковская улица': 9,
#  'Зональная улица': 6,
#  'Барвихинская улица': 39,
#  'Запорожская улица': 3,
#  'улица Маршала Неделина': 21,
#  'улица Красных Зорь': 27,
#  'Малая Филёвская улица': 36,
#  'Пинский проезд': 6,
#  'улица Барклая': 39,
#  'улица Толбухина': 12,
#  'Можайское шоссе': 39,
#  'Аминьевское шоссе': 48,
#  'Верейская улица': 30,
#  'Рябиновая улица': 90,
#  '2-й Поперечный проезд': 6,
#  'Абрамцевская улица': 36,
#  'улица Плещеева': 24,
#  'улица Конёнкова': 21,
#  'Илимская улица': 18,
#  'улица Говорова': 18,
#  'Вяземская улица': 9,
#  'Сколковское шоссе': 39,
#  'Беловежская улица': 36,
#  'Ярцевская улица': 24,
#  'улица Артамонова': 15,
#  'улица Кубинка': 9,
#  'улица Боженко': 6,
#  'Варшавское шоссе': 522,
#  'Сумская улица': 15,
#  'Кировоградская улица': 81,
#  'улица Красного Маяка': 48,
#  'Вологодский проезд': 15,
#  'улица Лётчика Бабушкина': 51,
#  'улица Менжинского': 54,
#  'Северодвинская улица': 18,
#  'Волгоградский проспект': 141,
#  'Славянский бульвар': 21,
#  'Кременчугская улица': 12,
#  'Гвардейская улица': 9,
#  'Давыдковская улица': 24,
#  'Староможайское шоссе': 9,
#  'Кутузовский проспект': 99,
#  'Большая Дорогомиловская улица': 27,
#  'Бережковская набережная': 24,
#  'Воробьёвское шоссе': 12,
#  'Мосфильмовская улица': 60,
#  'Мичуринский проспект': 123,
#  'улица Косыгина': 45,
#  'Ленинский проспект': 201,
#  'улица Большая Якиманка': 15,
#  'Якиманский проезд': 6,
#  'улица Серафимовича': 9,
#  'Стартовая улица': 36,
#  'проезд Шокальского': 39,
#  'улица Грекова': 21,
#  'Студёный проезд': 24,
#  'проезд Дежнёва': 39,
#  'Тайнинская улица': 18,
#  'Новозаводская улица': 36,
#  'Береговой проезд': 6,
#  'Новофилёвский проезд': 12,
#  'Филёвский бульвар': 27,
#  'Полярная улица': 72,
#  'улица Молодцова': 24,
#  'Ясный проезд': 36,
#  'Северный бульвар': 24,
#  'улица Бестужевых': 21,
#  'Инженерная улица': 18,
#  'Путевой проезд': 24,
#  'улица Декабристов': 45,
#  'улица Хачатуряна': 36,
#  'улица Санникова': 6,
#  'улица Мусоргского': 15,
#  'Челюскинская улица': 18,
#  'Юрловский проезд': 33,
#  'Партизанская улица': 33,
#  'Истринская улица': 9,
#  'Молдавская улица': 12,
#  'Житомирская улица': 3,
#  'Кастанаевская улица': 54,
#  'Молодогвардейская улица': 54,
#  'Заревый проезд': 9,
#  'Сельскохозяйственная улица': 51,
#  'улица Пестеля': 12,
#  'Чертановская улица': 198,
#  'Симферопольский бульвар': 75,
#  'улица 26-ти Бакинских Комиссаров': 27,
#  'Селигерская улица': 3,
#  'Бескудниковский переулок': 3,
#  'улица Академика Янгеля': 18,
#  'Станционная улица': 18,
#  'Россошанский проезд': 12,
#  '3-й Дорожный проезд': 30,
#  'Дорожная улица': 72,
#  'улица Подольских Курсантов': 51,
#  'Мирской переулок': 15,
#  'Холмогорская улица': 6,
#  'улица Римского-Корсакова': 27,
#  'улица Яблочкова': 33,
#  'улица Фонвизина': 15,
#  'улица Милашенкова': 30,
#  'Россошанская улица': 12,
#  'Сумской проезд': 21,
#  '1-я Останкинская улица': 36,
#  'Кольская улица': 18,
#  'Чонгарский бульвар': 39,
#  'Днепропетровская улица': 42,
#  'Печорская улица': 15,
#  'улица Гончарова': 12,
#  'улица Руставели': 27,
#  'Огородный проезд': 33,
#  '17-й проезд Марьиной Рощи': 6,
#  'Шереметьевская улица': 39,
#  '5-й проезд Марьиной Рощи': 6,
#  'Полковая улица': 3,
#  'улица Двинцев': 12,
#  'улица Грузинский Вал': 12,
#  'улица Пресненский Вал': 24,
#  'улица Трёхгорный Вал': 3,
#  'Шмитовский проезд': 39,
#  '2-й Красногвардейский проезд': 9,
#  'Новый Берингов проезд': 12,
#  'улица Сергея Макеева': 12,
#  'Стрелецкая улица': 3,
#  '3-й проезд Марьиной Рощи': 6,
#  'Востряковский проезд': 39,
#  'Булатниковская улица': 27,
#  'Медынская улица': 33,
#  'Харьковская улица': 12,
#  'Булатниковский проезд': 36,
#  'Болотниковская улица': 63,
#  'Большая Тульская улица': 21,
#  'Подольское шоссе': 6,
#  'Павловская улица': 3,
#  'Большая Серпуховская улица': 24,
#  'Серпуховская площадь': 6,
#  'улица Большая Полянка': 24,
#  'Люсиновская улица': 24,
#  'улица Добролюбова': 12,
#  'улица Советской Армии': 18,
#  'Трифоновская улица': 36,
#  'Олимпийский проспект': 21,
#  'улица Дурова': 15,
#  'Самотёчная улица': 6,
#  'Мясницкая улица': 9,
#  'Ростокинская улица': 15,
#  'Малахитовая улица': 24,
#  '1-й Ботанический проезд': 3,
#  'Лазоревый проезд': 6,
#  '2-й Ботанический проезд': 6,
#  'улица Седова': 6,
#  'проезд Русанова': 21,
#  'улица Докукина': 21,
#  'Краснопролетарская улица': 18,
#  'Останкинский проезд': 6,
#  'Селезнёвская улица': 9,
#  'Нахимовский проспект': 99,
#  'Коломенская улица': 33,
#  'улица Новинки': 15,
#  'проспект Андропова': 54,
#  'Нагатинская набережная': 51,
#  'Судостроительная улица': 81,
#  '1-й Нагатинский проезд': 6,
#  'Нагатинская улица': 45,
#  'Ереванская улица': 27,
#  'Кавказский бульвар': 42,
#  'Пролетарский проспект': 39,
#  'Каширское шоссе': 162,
#  'улица Каховка': 45,
#  'улица Намёткина': 9,
#  'Профсоюзная улица': 168,
#  'Страстной бульвар': 9,
#  'Долгоруковская улица': 18,
#  'Большая Переяславская улица': 12,
#  'Каланчёвская улица': 27,
#  'Русаковская улица': 36,
#  'улица Стромынка': 39,
#  'Электрозаводская улица': 36,
#  'Ферганский проезд': 27,
#  'Самаркандский бульвар': 33,
#  'улица Хлобыстова': 39,
#  'Ташкентская улица': 42,
#  'улица Образцова': 12,
#  'Перуновский переулок': 3,
#  'улица Новая Башиловка': 12,
#  'Балаклавский проспект': 57,
#  'улица Обручева': 57,
#  'Ферганская улица': 27,
#  '2-й Грайвороновский проезд': 24,
#  'Грайвороновская улица': 21,
#  'Люблинская улица': 123,
#  'Черноморский бульвар': 27,
#  'Ялтинская улица': 6,
#  'Стрельбищенский переулок': 18,
#  'Оружейный переулок': 6,
#  'Садовая-Триумфальная улица': 6,
#  'улица Павла Корчагина': 27,
#  'Новоалексеевская улица': 12,
#  '3-я Мытищинская улица': 6,
#  'площадь Академика Люльки': 6,
#  'улица Сокольнический Вал': 36,
#  'Поперечный просек': 42,
#  'Краснобогатырская улица': 60,
#  'Семёновская площадь': 9,
#  'Щербаковская улица': 15,
#  'Измайловский проспект': 27,
#  'Первомайская улица': 111,
#  'улица Измайловский Вал': 15,
#  'улица Преображенский Вал': 12,
#  'улица Олений Вал': 12,
#  'Большая Ширяевская улица': 12,
#  'Миллионная улица': 12,
#  'Новорязанская улица': 18,
#  'Бакунинская улица': 30,
#  'Вельяминовская улица': 12,
#  'Ткацкая улица': 24,
#  'Большая Оленья улица': 15,
#  'Халтуринская улица': 12,
#  'Большая Семёновская улица': 18,
#  'Спартаковская улица': 6,
#  'Ивантеевская улица': 48,
#  '1-я Прогонная улица': 3,
#  'Просторная улица': 12,
#  'Игральная улица': 9,
#  'улица Сайкина': 6,
#  'Велозаводская улица': 9,
#  'улица Ленинская Слобода': 12,
#  'улица Мастеркова': 9,
#  'Автозаводская улица': 48,
#  'Битцевский проезд': 18,
#  'Коломенская набережная': 33,
#  'улица Симоновский Вал': 27,
#  'улица Большие Каменщики': 18,
#  'Затонная улица': 15,
#  'Якорная улица': 15,
#  'улица Трофимова': 45,
#  'улица Газопровод': 18,
#  'Бойцовая улица': 24,
#  '4-я Гражданская улица': 6,
#  '1-я Рыбинская улица': 3,
#  'Водопроводный переулок': 6,
#  'Преображенская улица': 12,
#  'проспект Будённого': 99,
#  'улица Бориса Жигулёнкова': 12,
#  '8-я улица Соколиной Горы': 3,
#  'Сиреневый бульвар': 57,
#  'Щёлковский проезд': 6,
#  'Щёлковское шоссе': 111,
#  'Большая Черкизовская улица': 54,
#  'Преображенская площадь': 6,
#  'Вербная улица': 6,
#  'шоссе Энтузиастов': 234,
#  '2-й Полевой переулок': 9,
#  'Котляковская улица': 15,
#  '2-й Котляковский переулок': 9,
#  '1-й Варшавский проезд': 6,
#  'Каширский проезд': 3,
#  'Хабаровская улица': 54,
#  'улица Гастелло': 24,
#  '15-я Парковая улица': 36,
#  'улица Шумкина': 12,
#  'Старая Басманная улица': 21,
#  'улица Земляной Вал': 45,
#  'Костомаровский переулок': 18,
#  'улица Сергия Радонежского': 15,
#  'Новорогожская улица': 15,
#  'Севастопольский проспект': 141,
#  'Азовская улица': 24,
#  'Коломенское шоссе': 6,
#  'улица Садовники': 6,
#  'Коломенский проезд': 30,
#  'улица Академика Миллионщикова': 33,
#  'Зелёный проспект': 117,
#  '3-я Владимирская улица': 36,
#  '3-я Рыбинская улица': 6,
#  'Рабочая улица': 33,
#  'улица Лобачика': 6,
#  'Камчатская улица': 15,
#  'Сахалинская улица': 3,
#  'Уральская улица': 33,
#  '9-я Парковая улица': 36,
#  'Курганская улица': 12,
#  'Уссурийская улица': 18,
#  'Измайловский бульвар': 45,
#  '3-я Парковая улица': 36,
#  'улица Радио': 24,
#  'Бауманская улица': 36,
#  'Протопоповский переулок': 27,
#  'Делегатская улица': 3,
#  '3-й Самотёчный переулок': 15,
#  'улица Достоевского': 9,
#  'Ольховская улица': 6,
#  'Красноказарменная улица': 57,
#  'Байкальская улица': 45,
#  'Чусовская улица': 12,
#  'Иркутская улица': 9,
#  '2-й Иртышский проезд': 15,
#  'улица Бирюсинка': 21,
#  'Амурская улица': 30,
#  'Одесская улица': 12,
#  'улица Дмитрия Ульянова': 51,
#  'Нагорная улица': 45,
#  'Красноярская улица': 18,
#  'Алтайская улица': 39,
#  'Спартаковская площадь': 3,
#  'улица Молостовых': 33,
#  'Свободный проспект': 75,
#  'Вешняковская улица': 63,
#  'улица Красный Казанец': 48,
#  'Саянская улица': 27,
#  'улица Сталеваров': 48,
#  'улица Старый Гай': 12,
#  'Кетчерская улица': 30,
#  'Напольный проезд': 12,
#  'Снайперская улица': 9,
#  'улица Молдагуловой': 36,
#  'Фрязевская улица': 18,
#  'Мартеновская улица': 18,
#  'Новогиреевская улица': 42,
#  'Перовская улица': 63,
#  'Кусковская улица': 33,
#  'улица Плющева': 18,
#  'Электродная улица': 15,
#  'улица Уткина': 9,
#  'Окружной проезд': 39,
#  'Вольная улица': 18,
#  'Федеративный проспект': 42,
#  'улица Металлургов': 15,
#  '2-я Владимирская улица': 33,
#  'улица Плеханова': 42,
#  'Кусковский тупик': 3,
#  'улица Лазо': 15,
#  'Московский проспект': 33,
#  'Ломоносовский проспект': 96,
#  '1-я Владимирская улица': 30,
#  'Челябинская улица': 21,
#  'Большой Купавенский проезд': 21,
#  'Малый Купавенский проезд': 6,
#  '16-я Парковая улица': 27,
#  '106-й километр Московской Кольцевой Автодороги': 6,
#  '108-й километр Московской Кольцевой Автодороги': 6,
#  'улица Юности': 54,
#  'улица Паперника': 9,
#  'Рязанский проспект': 117,
#  'Монтажная улица': 24,
#  'Открытое шоссе': 78,
#  'Измайловское шоссе': 18,
#  'улица Чечулина': 24,
#  'Реутовская улица': 30,
#  'аллея Жемчуговой': 18,
#  'улица Академика Скрябина': 36,
#  'Электролитный проезд': 12,
#  'улица Ремизова': 15,
#  'проезд Карамзина': 39,
#  'Голубинская улица': 60,
#  'Ясногорская улица': 12,
#  'улица Айвазовского': 12,
#  'Тарусская улица': 15,
#  '5-я улица Соколиной Горы': 6,
#  'Яснополянская улица': 6,
#  'улица Михайлова': 33,
#  'улица Коновалова': 12,
#  'Кузьминская улица': 12,
#  'улица Миклухо-Маклая': 66,
#  'улица Введенского': 42,
#  'Нижегородская улица': 48,
#  'Таганская улица': 18,
#  'Оршанская улица': 6,
#  'улица Маршала Тимошенко': 18,
#  'Кунцевская улица': 6,
#  'Полоцкая улица': 9,
#  'улица Ивана Франко': 27,
#  'улица Василия Ботылёва': 15,
#  'Обводное шоссе': 9,
#  'улица Академика Павлова': 24,
#  'Новоясеневский проспект': 99,
#  'Литовский бульвар': 42,
#  '2-я Мякининская улица': 3,
#  'Бобруйская улица': 15,
#  'улица Екатерины Будановой': 6,
#  'улица Коцюбинского': 6,
#  'Никитский бульвар': 6,
#  '1-й Поперечный проезд': 6,
#  'улица Зацепский Вал': 12,
#  'улица Новый Арбат': 27,
#  '2-я улица Машиностроения': 33,
#  '1-я улица Машиностроения': 18,
#  'улица Вострухина': 9,
#  'Сормовская улица': 12,
#  '7-я Парковая улица': 15,
#  '5-я Парковая улица': 21,
#  'Зубовская улица': 6,
#  'улица Пречистенка': 21,
#  'Гоголевский бульвар': 18,
#  'улица Юных Ленинцев': 69,
#  'Таганская площадь': 9,
#  'Верхняя Радищевская улица': 9,
#  'Яузская улица': 12,
#  'Москворецкая набережная': 18,
#  'Кремлёвская набережная': 6,
#  'Пречистенская набережная': 6,
#  'Подгорская набережная': 3,
#  'Нижняя Радищевская улица': 6,
#  'улица Александра Солженицына': 9,
#  'Николоямская улица': 30,
#  'Андроньевский проезд': 6,
#  'Волочаевская улица': 39,
#  'Душинская улица': 6,
#  'Главная улица': 3,
#  'Воронцовская улица': 18,
#  '1-я Дубровская улица': 24,
#  'Шарикоподшипниковская улица': 36,
#  '1-й Сетуньский проезд': 6,
#  '4-й Сетуньский проезд': 3,
#  '2-й Сетуньский проезд': 6,
#  'улица Покровка': 24,
#  'улица Маросейка': 6,
#  'Авиамоторная улица': 72,
#  '2-я Кабельная улица': 3,
#  '2-й Кабельный проезд': 3,
#  'Славянская площадь': 18,
#  'Новочерёмушкинская улица': 51,
#  'проезд Стройкомбината': 12,
#  'Очаковское шоссе': 18,
#  'Матвеевская улица': 24,
#  'Веерная улица': 30,
#  'Нежинская улица': 30,
#  'Староволынская улица': 18,
#  'проспект Вернадского': 189,
#  'Красноармейская улица': 21,
#  'Тверской бульвар': 18,
#  'улица Гарибальди': 30,
#  'улица Архитектора Власова': 27,
#  'Комсомольский проспект': 69,
#  'улица Остоженка': 18,
#  'Подольская улица': 18,
#  'улица Перерва': 81,
#  'улица Нижние Поля': 24,
#  'Волжский бульвар': 75,
#  'Саратовская улица': 18,
#  'улица Лобачевского': 69,
#  'Керченская улица': 12,
#  'Окская улица': 24,
#  'улица Фёдора Полетаева': 24,
#  'Жигулёвская улица': 9,
#  'улица Шкулёва': 12,
#  'Университетский проспект': 42,
#  'Семёновский проезд': 21,
#  'улица Семёновский Вал': 6,
#  'Доброслободская улица': 18,
#  'Новая Басманная улица': 21,
#  'Красноворотский проезд': 3,
#  'Белореченская улица': 45,
#  'Краснодарская улица': 60,
#  'улица Полбина': 45,
#  'Шоссейная улица': 102,
#  'улица Гурьянова': 48,
#  'Перовское шоссе': 30,
#  'шоссе Фрезер': 36,
#  '5-я Кабельная улица': 21,
#  'Новочеркасский бульвар': 42,
#  'Донецкая улица': 27,
#  'улица Олеко Дундича': 6,
#  'улица Маршала Голованова': 21,
#  'улица Горбунова': 21,
#  'улица Судакова': 15,
#  'Краснодонская улица': 57,
#  'Южнопортовая улица': 60,
#  'улица Коштоянца': 21,
#  'улица Удальцова': 54,
#  'Багратионовский проезд': 12,
#  'улица Полосухина': 3,
#  'Батайский проезд': 39,
#  'Ставропольская улица': 66,
#  '13-я Парковая улица': 9,
#  'Измайловская площадь': 6,
#  'Измайловский проезд': 6,
#  'Никитинская улица': 18,
#  '3-я Прядильная улица': 3,
#  '1-я Парковая улица': 6,
#  'Тихорецкий бульвар': 15,
#  'улица Рогожский Вал': 18,
#  'Абельмановская улица': 9,
#  '3-й Крутицкий переулок': 24,
#  'Солдатская улица': 6,
#  'Угрешская улица': 33,
#  'Большая Андроньевская улица': 12,
#  'Зеленодольский проезд': 6,
#  'улица Академика Волгина': 27,
#  'улица Островитянова': 66,
#  'проспект 60-летия Октября': 33,
#  'Садовая-Черногрязская улица': 9,
#  'Лермонтовская площадь': 6,
#  'Садовая-Спасская улица': 12,
#  'Малая Сухаревская площадь': 9,
#  'Самотёчная площадь': 6,
#  'Садовая-Самотёчная улица': 12,
#  'Большая Садовая улица': 6,
#  'Садовая-Кудринская улица': 18,
#  'Зубовский бульвар': 12,
#  'улица Крымский Вал': 9,
#  'Валовая улица': 9,
#  'Большой Краснохолмский мост': 6,
#  'улица Пржевальского': 12,
#  'Большая Очаковская улица': 39,
#  'Никулинская улица': 30,
#  'Банный переулок': 6,
#  'Новосущёвский переулок': 12,
#  'Минаевский переулок': 6,
#  'улица Николая Химушина': 12,
#  'улица Академика Челомея': 9,
#  'улица Новаторов': 30,
#  'улица Воронцовские Пруды': 3,
#  'Вильнюсская улица': 12,
#  'Озёрная улица': 36,
#  'улица Бутлерова': 21,
#  'Мытная улица': 24,
#  'улица Шухова': 3,
#  'улица Академика Пилюгина': 36,
#  'улица Кравченко': 30,
#  'улица Воейкова': 6,
#  'улица Михаила Певцова': 6,
#  'улица Семёнова-Тян-Шанского': 6,
#  'Лубянская площадь': 15,
#  'Устьинская набережная': 3,
#  'улица Марии Ульяновой': 15,
#  'улица Академика Хохлова': 12,
#  'улица Лебедева': 15,
#  'улица Паустовского': 12,
#  'Борисовский проезд': 36,
#  'Смоленская улица': 6,
#  'проезд Нансена': 6,
#  'Грузинский переулок': 3,
#  'Ясеневая улица': 51,
#  'Фрунзенская набережная': 42,
#  'Сущёвская улица': 15,
#  'Нововоротниковский переулок': 3,
#  'Большая Грузинская улица': 18,
#  'Малая Грузинская улица': 18,
#  'Конюшковская улица': 12,
#  'улица Барышиха': 60,
#  'улица Борисовские Пруды': 60,
#  'Малая Андроньевская улица': 6,
#  'Братеевская улица': 33,
#  'Хордовый проезд': 18,
#  'Паромная улица': 15,
#  'Дубининская улица': 42,
#  'Холодильный переулок': 18,
#  'улица Даниловский Вал': 12,
#  'Елецкая улица': 15,
#  'площадь Крестьянская Застава': 6,
#  'Воронежская улица': 39,
#  'Сокольническая площадь': 6,
#  'Иловайская улица': 18,
#  'Верхняя Красносельская улица': 27,
#  'Липецкая улица': 57,
#  'Бакинская улица': 24,
#  'улица Москворечье': 30,
#  'Промышленная улица': 24,
#  'Деловая улица': 6,
#  'улица Кошкина': 9,
#  'Кантемировская улица': 45,
#  'улица Бехтерева': 33,
#  'Севанская улица': 24,
#  'Ряжская улица': 12,
#  'Бирюлёвская улица': 36,
#  'Касимовская улица': 15,
#  'Лебедянская улица': 45,
#  'Загорьевская улица': 15,
#  'Михневская улица': 24,
#  'улица Серпуховский Вал': 33,
#  'Загорьевский проезд': 24,
#  'Каспийская улица': 54,
#  'улица Медиков': 18,
#  'Шипиловская улица': 45,
#  'Шипиловский проезд': 63,
#  'Домодедовская улица': 39,
#  'Ореховый бульвар': 75,
#  'улица Маршала Захарова': 24,
#  'Элеваторная улица': 3,
#  'Товарищеская улица': 3,
#  'Новоспасский проезд': 15,
#  'Новохохловская улица': 18,
#  'Луганская улица': 12,
#  'Полимерная улица': 6,
#  '3-й Павелецкий проезд': 18,
#  'Павелецкая набережная': 9,
#  'Дербеневская набережная': 18,
#  'Кожевническая улица': 27,
#  'Носовихинское шоссе': 18,
#  'Городецкая улица': 24,
#  'Новокосинская улица': 42,
#  'Салтыковская улица': 75,
#  'улица Улофа Пальме': 3,
#  'улица Довженко': 18,
#  'улица Винокурова': 21,
#  'улица Шверника': 12,
#  'улица Гримау': 12,
#  'Менделеевская улица': 9,
#  'улица Богатырский Мост': 9,
#  'Елоховская площадь': 3,
#  '1-й Дербеневский переулок': 6,
#  'улица Маршала Чуйкова': 18,
#  'Михневский проезд': 12,
#  'Никольско-Архангельский проезд': 9,
#  '2-й километр Московской Кольцевой Автодороги': 6,
#  '3-й километр Московской Кольцевой Автодороги': 6,
#  'Задонский проезд': 33,
#  'улица Мусы Джалиля': 45,
#  'Ореховый проезд': 15,
#  'улица Генерала Белова': 42,
#  'Кустанайская улица': 15,
#  'Гурьевский проезд': 24,
#  'Тамбовская улица': 6,
#  'Зеленодольская улица': 12,
#  'улица Маршала Шестопалова': 21,
#  'улица Павла Андреева': 3,
#  'Ключевая улица': 30,
#  'Нижняя Краснохолмская улица': 3,
#  'Даниловская набережная': 12,
#  'Алма-Атинская улица': 6,
#  'улица Галины Вишневской': 3,
#  'Суздальская улица': 48,
#  'улица Строителей': 15,
#  'Юрьевский переулок': 12,
#  'Ухтомская улица': 15,
#  'Нагорный проезд': 18,
#  'улица Шаболовка': 30,
#  'улица Кржижановского': 42,
#  'Большая Черёмушкинская улица': 60,
#  'Загородное шоссе': 42,
#  'улица Вавилова': 69,
#  'улица Орджоникидзе': 12,
#  'Новокузнецкая улица': 18,
#  'Садовнический проезд': 12,
#  'Устьинский проезд': 12,
#  'Яузский бульвар': 3,
#  'Хохловская площадь': 3,
#  'Чистопрудный бульвар': 12,
#  'Покровский бульвар': 9,
#  'Лосиноостровская улица': 48,
#  'Пермская улица': 18,
#  '6-й Лучевой просек': 9,
#  'Белокаменное шоссе': 6,
#  'Яузская аллея': 30,
#  '6-я Радиальная улица': 21,
#  'Пятницкая улица': 15,
#  'улица Большая Ордынка': 18,
#  'Большой Москворецкий мост': 12,
#  '2-й Боткинский проезд': 9,
#  '1-й Боткинский проезд': 6,
#  'улица Матросская Тишина': 27,
#  'Большая Почтовая улица': 24,
#  'Малая Почтовая улица': 9,
#  '1-й Капотнинский проезд': 24,
#  'улица Верхние Поля': 78,
#  'Чагинская улица': 18,
#  'улица Капотня': 39,
#  '14-й километр Московской Кольцевой Автодороги': 6,
#  '11-й километр Московской Кольцевой Автодороги': 9,
#  'улица Цюрупы': 24,
#  'улица Крупской': 12,
#  'улица Свержевского': 6,
#  'Кубанская улица': 3,
#  'Курская улица': 3,
#  '7-я улица Текстильщиков': 3,
#  'Новоцарицынское шоссе': 21,
#  '1-я Радиальная улица': 3,
#  '3-я Радиальная улица': 12,
#  '40-й километр Московской Кольцевой Автодороги': 6,
#  '38-й километр Московской Кольцевой Автодороги': 6,
#  '37-й километр Московской Кольцевой Автодороги': 6,
#  '35-й километр Московской Кольцевой Автодороги': 6,
#  '34-й километр Московской Кольцевой Автодороги': 12,
#  '33-й километр Московской Кольцевой Автодороги': 6,
#  '32-й километр Московской Кольцевой Автодороги': 12,
#  '31-й километр Московской Кольцевой Автодороги': 6,
#  '29-й километр Московской Кольцевой Автодороги': 6,
#  '27-й километр Московской Кольцевой Автодороги': 6,
#  '25-й километр Московской Кольцевой Автодороги': 3,
#  'Шелепихинский мост': 3,
#  '2-я Брестская улица': 6,
#  'улица Тёплый Стан': 42,
#  'проезд Одоевского': 12,
#  'улица Чурилиха': 9,
#  'Малая Тульская улица': 15,
#  'улица Раменки': 12,
#  'улица Кедрова': 12,
#  'Новоостаповская улица': 15,
#  'улица Инессы Арманд': 15,
#  'Тропарёвская улица': 21,
#  '7-я Кожуховская улица': 12,
#  'улица Петра Романова': 3,
#  '6-я Кожуховская улица': 6,
#  'Новомарьинская улица': 36,
#  'улица Ивана Бабушкина': 6,
#  'Соймоновский проезд': 3,
#  'улица Академика Варги': 33,
#  'Рочдельская улица': 12,
#  'улица Генерала Тюленева': 24,
#  '3-я Никопольская улица': 3,
#  'Мелитопольская улица': 3,
#  'проезд Олимпийской Деревни': 9,
#  'улица Рокотова': 9,
#  'Соловьиный проезд': 18,
#  'Боровское шоссе': 198,
#  'Солнцевский проспект': 24,
#  'улица Богданова': 24,
#  '48-й километр Московской Кольцевой Автодороги': 9,
#  'улица Академика Анохина': 48,
#  'улица Академика Бакулева': 18,
#  'Санаторная аллея': 6,
#  'Теплостанский проезд': 3,
#  'Троекуровский проезд': 9,
#  'улица Тюрина': 3,
#  'Попутная улица': 21,
#  'улица 50 лет Октября': 24,
#  'Донбасская улица': 3,
#  'Верхняя Сыромятническая улица': 6,
#  'Гаврикова улица': 6,
#  'Марксистская улица': 30,
#  'бульвар Энтузиастов': 9,
#  'Инициативная улица': 12,
#  'Елизаветинский переулок': 6,
#  '1-й Сыромятнический переулок': 3,
#  '3-й Сыромятнический переулок': 12,
#  '1-я Магистральная улица': 12,
#  '2-я Магистральная улица': 18,
#  'Большая Марфинская улица': 6,
#  'Суворовская площадь': 12,
#  'Артековская улица': 3,
#  '1-й Вешняковский проезд': 6,
#  'улица Приорова': 6,
#  'Пересветов переулок': 3,
#  'улица Головачёва': 6,
#  'улица Комдива Орлова': 12,
#  'площадь Соловецких Юнг': 15,
#  'Совхозная улица': 24,
#  'улица Чистова': 9,
#  'Рузская улица': 3,
#  'Новороссийская улица': 21,
#  'улица Академика Капицы': 9,
#  'Мазиловская улица': 6,
#  'улица Покрышкина': 15,
#  'Домостроительная улица': 15,
#  'Малая Набережная улица': 3,
#  'улица Генерала Дорохова': 33,
#  'Электрозаводский мост': 12,
#  'Пятницкое шоссе': 69,
#  'Дубравная улица': 33,
#  '1-й Митинский переулок': 12,
#  ...}

# %%
sorted(streets.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('проезд без названия', 619),
#  ('Варшавское шоссе', 174),
#  ('Калужское шоссе', 113),
#  ('шоссе Энтузиастов', 78),
#  ('проспект Мира', 73),
#  ('Дмитровское шоссе', 69),
#  ('Ленинский проспект', 67),
#  ('Чертановская улица', 66),
#  ('Боровское шоссе', 66),
#  ('проспект Вернадского', 63),
#  ('Ленинградское шоссе', 57),
#  ('Профсоюзная улица', 56),
#  ('Каширское шоссе', 54),
#  ('Алтуфьевское шоссе', 47),
#  ('Волгоградский проспект', 47),
#  ('Севастопольский проспект', 47),
#  ('Волоколамское шоссе', 46),
#  ('Центральная улица', 44),
#  ('Мичуринский проспект', 41),
#  ('Люблинская улица', 41),
#  ('Рублёвское шоссе', 40),
#  ('Зелёный проспект', 39),
#  ('Рязанский проспект', 39),
#  ('улица Героев Панфиловцев', 37),
#  ('Первомайская улица', 37),
#  ('Щёлковское шоссе', 37),
#  ('Ленинградский проспект', 35),
#  ('улица Свободы', 34),
#  ('Шоссейная улица', 34),
#  ('Кутузовский проспект', 33),
#  ('Нахимовский проспект', 33),
#  ('проспект Будённого', 33),
#  ('Новоясеневский проспект', 33),
#  ('Ломоносовский проспект', 32),
#  ('Киевское шоссе', 32),
#  ('Привольная улица', 32),
#  ('Рябиновая улица', 30),
#  ('Дубнинская улица', 29),
#  ('Кировоградская улица', 27),
#  ('Судостроительная улица', 27),
#  ('улица Перерва', 27),
#  ('Открытое шоссе', 26),
#  ('улица Верхние Поля', 26),
#  ('Большая Академическая улица', 25),
#  ('Симферопольский бульвар', 25),
#  ('Свободный проспект', 25),
#  ('Волжский бульвар', 25),
#  ('Ореховый бульвар', 25),
#  ('Салтыковская улица', 25),
#  ('улица Александры Монаховой', 25),
#  ('Коровинское шоссе', 24),
#  ('Фестивальная улица', 24),
#  ('улица Народного Ополчения', 24),
#  ('Ярославское шоссе', 24),
#  ('Полярная улица', 24),
#  ('Дорожная улица', 24),
#  ('Авиамоторная улица', 24),
#  ('проспект Маршала Жукова', 23),
#  ('Широкая улица', 23),
#  ('улица Юных Ленинцев', 23),
#  ('Комсомольский проспект', 23),
#  ('улица Лобачевского', 23),
#  ('улица Вавилова', 23),
#  ('Пятницкое шоссе', 23),
#  ('Енисейская улица', 22),
#  ('улица Миклухо-Маклая', 22),
#  ('Ставропольская улица', 22),
#  ('улица Островитянова', 22),
#  ('Бескудниковский бульвар', 21),
#  ('Кронштадтский бульвар', 21),
#  ('Тимирязевская улица', 21),
#  ('Хорошёвское шоссе', 21),
#  ('Болотниковская улица', 21),
#  ('Вешняковская улица', 21),
#  ('Перовская улица', 21),
#  ('Шипиловский проезд', 21),
#  ('улица Александра Печерского', 21),
#  ('Крылатская улица', 20),
#  ('Мосфильмовская улица', 20),
#  ('Краснобогатырская улица', 20),
#  ('Голубинская улица', 20),
#  ('Краснодарская улица', 20),
#  ('Южнопортовая улица', 20),
#  ('улица Барышиха', 20),
#  ('улица Борисовские Пруды', 20),
#  ('Большая Черёмушкинская улица', 20),
#  ('Панфиловский проспект', 20),
#  ('Балаклавский проспект', 19),
#  ('улица Обручева', 19),
#  ('Сиреневый бульвар', 19),
#  ('Красноказарменная улица', 19),
#  ('Краснодонская улица', 19),
#  ('Липецкая улица', 19),
#  ('улица Лескова', 18),
#  ('Таллинская улица', 18),
#  ('улица Менжинского', 18),
#  ('Кастанаевская улица', 18),
#  ('Молодогвардейская улица', 18),
#  ('проспект Андропова', 18),
#  ('Большая Черкизовская улица', 18),
#  ('Хабаровская улица', 18),
#  ('улица Юности', 18),
#  ('улица Удальцова', 18),
#  ('Каспийская улица', 18),
#  ('Южнобутовская улица', 18),
#  ('Чечёрский проезд', 18),
#  ('Смольная улица', 17),
#  ('улица Академика Королёва', 17),
#  ('улица Кулакова', 17),
#  ('бульвар Яна Райниса', 17),
#  ('улица Крылатские Холмы', 17),
#  ('улица Лётчика Бабушкина', 17),
#  ('Сельскохозяйственная улица', 17),
#  ('улица Подольских Курсантов', 17),
#  ('Нагатинская набережная', 17),
#  ('улица Дмитрия Ульянова', 17),
#  ('Новочерёмушкинская улица', 17),
#  ('Ясеневая улица', 17),
#  ('улица Сущёвский Вал', 16),
#  ('Бутырская улица', 16),
#  ('улица Маршала Бирюзова', 16),
#  ('улица Маршала Катукова', 16),
#  ('улица Генерала Белобородова', 16),
#  ('Живописная улица', 16),
#  ('Большая Филёвская улица', 16),
#  ('Череповецкая улица', 16),
#  ('Аминьевское шоссе', 16),
#  ('улица Красного Маяка', 16),
#  ('Ивантеевская улица', 16),
#  ('Автозаводская улица', 16),
#  ('улица Красный Казанец', 16),
#  ('улица Сталеваров', 16),
#  ('Нижегородская улица', 16),
#  ('улица Гурьянова', 16),
#  ('Суздальская улица', 16),
#  ('Лосиноостровская улица', 16),
#  ('улица Академика Анохина', 16),
#  ('Новокуркинское шоссе', 16),
#  ('Михалковская улица', 15),
#  ('улица Корнейчука', 15),
#  ('Авиационная улица', 15),
#  ('Продольный проезд', 15),
#  ('Минская улица', 15),
#  ('улица Косыгина', 15),
#  ('улица Декабристов', 15),
#  ('Нагатинская улица', 15),
#  ('улица Каховка', 15),
#  ('улица Трофимова', 15),
#  ('улица Земляной Вал', 15),
#  ('Измайловский бульвар', 15),
#  ('Байкальская улица', 15),
#  ('Нагорная улица', 15),
#  ('Белореченская улица', 15),
#  ('улица Полбина', 15),
#  ('Кантемировская улица', 15),
#  ('Лебедянская улица', 15),
#  ('Шипиловская улица', 15),
#  ('улица Мусы Джалиля', 15),
#  ('улица Авиаторов', 15),
#  ('улица Адмирала Лазарева', 15),
#  ('улица Марьинский Парк', 15),
#  ('Большой бульвар', 15),
#  ('улица Зои и Александра Космодемьянских', 14),
#  ('Ангарская улица', 14),
#  ('Митинская улица', 14),
#  ('Зеленоградская улица', 14),
#  ('Ботаническая улица', 14),
#  ('улица Исаковского', 14),
#  ('Таманская улица', 14),
#  ('Днепропетровская улица', 14),
#  ('Кавказский бульвар', 14),
#  ('Ташкентская улица', 14),
#  ('Поперечный просек', 14),
#  ('Новогиреевская улица', 14),
#  ('Федеративный проспект', 14),
#  ('улица Плеханова', 14),
#  ('улица Введенского', 14),
#  ('Литовский бульвар', 14),
#  ('Университетский проспект', 14),
#  ('Новочеркасский бульвар', 14),
#  ('Фрунзенская набережная', 14),
#  ('Дубининская улица', 14),
#  ('Новокосинская улица', 14),
#  ('улица Генерала Белова', 14),
#  ('улица Кржижановского', 14),
#  ('Загородное шоссе', 14),
#  ('улица Тёплый Стан', 14),
#  ('Поречная улица', 14),
#  ('улица Адмирала Корнилова', 14),
#  ('Заводская улица', 14),
#  ('проспект Генерала Алексеева', 14),
#  ('улица 800-летия Москвы', 13),
#  ('Флотская улица', 13),
#  ('Планерная улица', 13),
#  ('Новощукинская улица', 13),
#  ('улица Вилиса Лациса', 13),
#  ('Барвихинская улица', 13),
#  ('улица Барклая', 13),
#  ('Можайское шоссе', 13),
#  ('Сколковское шоссе', 13),
#  ('проезд Шокальского', 13),
#  ('проезд Дежнёва', 13),
#  ('Чонгарский бульвар', 13),
#  ('Шереметьевская улица', 13),
#  ('Шмитовский проезд', 13),
#  ('Востряковский проезд', 13),
#  ('Пролетарский проспект', 13),
#  ('улица Стромынка', 13),
#  ('улица Хлобыстова', 13),
#  ('Алтайская улица', 13),
#  ('Окружной проезд', 13),
#  ('проезд Карамзина', 13),
#  ('Волочаевская улица', 13),
#  ('Батайский проезд', 13),
#  ('Большая Очаковская улица', 13),
#  ('Воронежская улица', 13),
#  ('Домодедовская улица', 13),
#  ('улица Капотня', 13),
#  ('бульвар Дмитрия Донского', 13),
#  ('Большая Косинская улица', 13),
#  ('Лухмановская улица', 13),
#  ('Остафьевское шоссе', 13),
#  ('Клязьминская улица', 12),
#  ('Сходненская улица', 12),
#  ('Большая Пироговская улица', 12),
#  ('улица Берзарина', 12),
#  ('улица Нижние Мнёвники', 12),
#  ('Малая Филёвская улица', 12),
#  ('Абрамцевская улица', 12),
#  ('Беловежская улица', 12),
#  ('Стартовая улица', 12),
#  ('Новозаводская улица', 12),
#  ('Ясный проезд', 12),
#  ('улица Хачатуряна', 12),
#  ('1-я Останкинская улица', 12),
#  ('Булатниковский проезд', 12),
#  ('Трифоновская улица', 12),
#  ('Русаковская улица', 12),
#  ('Электрозаводская улица', 12),
#  ('улица Сокольнический Вал', 12),
#  ('15-я Парковая улица', 12),
#  ('3-я Владимирская улица', 12),
#  ('9-я Парковая улица', 12),
#  ('3-я Парковая улица', 12),
#  ('Бауманская улица', 12),
#  ('улица Молдагуловой', 12),
#  ('улица Академика Скрябина', 12),
#  ('Шарикоподшипниковская улица', 12),
#  ('шоссе Фрезер', 12),
#  ('Озёрная улица', 12),
#  ('улица Академика Пилюгина', 12),
#  ('Борисовский проезд', 12),
#  ('Бирюлёвская улица', 12),
#  ('Новомарьинская улица', 12),
#  ('Родниковая улица', 12),
#  ('Венёвская улица', 12),
#  ('Центральный проспект', 12),
#  ('улица Ленина', 12),
#  ('Саларьевская улица', 12),
#  ('Онежская улица', 11),
#  ('Коптевская улица', 11),
#  ('улица Василия Петушкова', 11),
#  ('улица Куусинена', 11),
#  ('улица Маршала Тухачевского', 11),
#  ('Карамышевская набережная', 11),
#  ('улица Коминтерна', 11),
#  ('Лодочная улица', 11),
#  ('улица Твардовского', 11),
#  ('Бибиревская улица', 11),
#  ('Юрловский проезд', 11),
#  ('Партизанская улица', 11),
#  ('улица Яблочкова', 11),
#  ('Огородный проезд', 11),
#  ('Медынская улица', 11),
#  ('Коломенская улица', 11),
#  ('Самаркандский бульвар', 11),
#  ('Коломенская набережная', 11),
#  ('улица Академика Миллионщикова', 11),
#  ('Рабочая улица', 11),
#  ('Уральская улица', 11),
#  ('улица Молостовых', 11),
#  ('Кусковская улица', 11),
#  ('2-я Владимирская улица', 11),
#  ('Московский проспект', 11),
#  ('улица Михайлова', 11),
#  ('2-я улица Машиностроения', 11),
#  ('Угрешская улица', 11),
#  ('проспект 60-летия Октября', 11),
#  ('Братеевская улица', 11),
#  ('улица Бехтерева', 11),
#  ('улица Серпуховский Вал', 11),
#  ('Задонский проезд', 11),
#  ('улица Академика Варги', 11),
#  ('улица Генерала Дорохова', 11),
#  ('Дубравная улица', 11),
#  ('Мячковский бульвар', 11),
#  ('улица 8 Марта', 11),
#  ('Бартеневская улица', 11),
#  ('Советская улица', 11),
#  ('Соколово-Мещерская улица', 11),
#  ('Солнечная улица', 11),
#  ('улица Каменка', 11),
#  ('Сосновая аллея', 11),
#  ('улица Брусилова', 11),
#  ('Железнодорожная улица', 11),
#  ('Октябрьский проспект', 11),
#  ('2-й Лихачёвский переулок', 11),
#  ('улица Светланова', 11),
#  ('улица Генерала Донскова', 11),
#  ('Беломорская улица', 10),
#  ('улица Дыбенко', 10),
#  ('Херсонская улица', 10),
#  ('Анадырский проезд', 10),
#  ('Изумрудная улица', 10),
#  ('Радужная улица', 10),
#  ('проезд Серебрякова', 10),
#  ('Туристская улица', 10),
#  ('улица Фабрициуса', 10),
#  ('Осенний бульвар', 10),
#  ('3-я Хорошёвская улица', 10),
#  ('Осташковская улица', 10),
#  ('Верейская улица', 10),
#  ('3-й Дорожный проезд', 10),
#  ('улица Милашенкова', 10),
#  ('Бакунинская улица', 10),
#  ('Коломенский проезд', 10),
#  ('Амурская улица', 10),
#  ('Кетчерская улица', 10),
#  ('1-я Владимирская улица', 10),
#  ('Реутовская улица', 10),
#  ('Николоямская улица', 10),
#  ('Веерная улица', 10),
#  ('Нежинская улица', 10),
#  ('улица Гарибальди', 10),
#  ('Перовское шоссе', 10),
#  ('Никулинская улица', 10),
#  ('улица Новаторов', 10),
#  ('улица Кравченко', 10),
#  ('улица Москворечье', 10),
#  ('Ключевая улица', 10),
#  ('улица Шаболовка', 10),
#  ('Яузская аллея', 10),
#  ('Марксистская улица', 10),
#  ('Старобитцевская улица', 10),
#  ('улица Поляны', 10),
#  ('2-я Вольская улица', 10),
#  ('Братиславская улица', 10),
#  ('улица Бунинская Аллея', 10),
#  ('Харьковский проезд', 10),
#  ('улица Андреевка', 10),
#  ('Георгиевский проспект', 10),
#  ('Муравская улица', 10),
#  ('Покровская улица', 10),
#  ('Рязановское шоссе', 10),
#  ('Староникольская улица', 10),
#  ('улица Бориса Пастернака', 10),
#  ('Соболевский проезд', 10),
#  ('улица Мнёвники', 9),
#  ('Звенигородское шоссе', 9),
#  ('улица Малыгина', 9),
#  ('Снежная улица', 9),
#  ('улица Бориса Галушкина', 9),
#  ('Лобненская улица', 9),
#  ('Строгинский бульвар', 9),
#  ('улица Софьи Ковалевской', 9),
#  ('Берёзовая аллея', 9),
#  ('Сигнальный проезд', 9),
#  ('улица Пришвина', 9),
#  ('улица Красных Зорь', 9),
#  ('Большая Дорогомиловская улица', 9),
#  ('Филёвский бульвар', 9),
#  ('улица 26-ти Бакинских Комиссаров', 9),
#  ('улица Римского-Корсакова', 9),
#  ('улица Руставели', 9),
#  ('Булатниковская улица', 9),
#  ('Ереванская улица', 9),
#  ('Каланчёвская улица', 9),
#  ('Ферганский проезд', 9),
#  ('Ферганская улица', 9),
#  ('Черноморский бульвар', 9),
#  ('улица Павла Корчагина', 9),
#  ('Измайловский проспект', 9),
#  ('улица Симоновский Вал', 9),
#  ('Протопоповский переулок', 9),
#  ('Саянская улица', 9),
#  ('16-я Парковая улица', 9),
#  ('улица Ивана Франко', 9),
#  ('улица Новый Арбат', 9),
#  ('улица Архитектора Власова', 9),
#  ('Донецкая улица', 9),
#  ('улица Академика Волгина', 9),
#  ('Верхняя Красносельская улица', 9),
#  ('Кожевническая улица', 9),
#  ('улица Матросская Тишина', 9),
#  ('улица Шолохова', 9),
#  ('улица Скульптора Мухиной', 9),
#  ('Лукинская улица', 9),
#  ('улица Николая Старостина', 9),
#  ('улица Маршала Полубоярова', 9),
#  ('улица Генерала Кузнецова', 9),
#  ('улица Верхняя Масловка', 9),
#  ('улица Горчакова', 9),
#  ('Перервинский бульвар', 9),
#  ('Ярославская улица', 9),
#  ('улица Руднёвка', 9),
#  ('Большая Никитская улица', 9),
#  ('улица Лётчика Спирина', 9),
#  ('Лесная улица', 9),
#  ('проспект 40 лет Октября', 9),
#  ('Большая Калитниковская улица', 9),
#  ('Тверская улица', 9),
#  ('Старопетровский проезд', 8),
#  ('Петрозаводская улица', 8),
#  ('Петровско-Разумовский проезд', 8),
#  ('улица Бутырский Вал', 8),
#  ('Новослободская улица', 8),
#  ('улица Плющиха', 8),
#  ('улица Красная Пресня', 8),
#  ('Башиловская улица', 8),
#  ('улица Нижняя Масловка', 8),
#  ('Новопесчаная улица', 8),
#  ('проезд Донелайтиса', 8),
#  ('Ельнинская улица', 8),
#  ('Богородское шоссе', 8),
#  ('Тушинская площадь', 8),
#  ('Прибрежный проезд', 8),
#  ('Неманский проезд', 8),
#  ('1-й Силикатный проезд', 8),
#  ('Костромская улица', 8),
#  ('Осенняя улица', 8),
#  ('улица Плещеева', 8),
#  ('Ярцевская улица', 8),
#  ('Давыдковская улица', 8),
#  ('Бережковская набережная', 8),
#  ('Студёный проезд', 8),
#  ('улица Молодцова', 8),
#  ('Северный бульвар', 8),
#  ('Путевой проезд', 8),
#  ('улица Пресненский Вал', 8),
#  ('Большая Серпуховская улица', 8),
#  ('улица Большая Полянка', 8),
#  ('Люсиновская улица', 8),
#  ('Малахитовая улица', 8),
#  ('2-й Грайвороновский проезд', 8),
#  ('Ткацкая улица', 8),
#  ('Бойцовая улица', 8),
#  ('улица Гастелло', 8),
#  ('Азовская улица', 8),
#  ('улица Радио', 8),
#  ('Монтажная улица', 8),
#  ('улица Чечулина', 8),
#  ('улица Академика Павлова', 8),
#  ('1-я Дубровская улица', 8),
#  ('улица Покровка', 8),
#  ('Матвеевская улица', 8),
#  ('улица Нижние Поля', 8),
#  ('Окская улица', 8),
#  ('улица Фёдора Полетаева', 8),
#  ('3-й Крутицкий переулок', 8),
#  ('Мытная улица', 8),
#  ('Бакинская улица', 8),
#  ('Промышленная улица', 8),
#  ('Севанская улица', 8),
#  ('Михневская улица', 8),
#  ('Загорьевский проезд', 8),
#  ('улица Маршала Захарова', 8),
#  ('Городецкая улица', 8),
#  ('Гурьевский проезд', 8),
#  ('Большая Почтовая улица', 8),
#  ('1-й Капотнинский проезд', 8),
#  ('улица Цюрупы', 8),
#  ('улица Генерала Тюленева', 8),
#  ('Солнцевский проспект', 8),
#  ('улица Богданова', 8),
#  ('улица 50 лет Октября', 8),
#  ('Совхозная улица', 8),
#  ('улица Грина', 8),
#  ('Скобелевская улица', 8),
#  ('Приречная улица', 8),
#  ('улица Авиаконструктора Миля', 8),
#  ('Изюмская улица', 8),
#  ('улица Академика Семёнова', 8),
#  ('Никольский проезд', 8),
#  ('Фирсановское шоссе', 8),
#  ('улица Авиаконструктора Сухого', 8),
#  ('улица Маршала Савицкого', 8),
#  ('Косинская улица', 8),
#  ('Внуковское шоссе', 8),
#  ('Косинское шоссе', 8),
#  ('Московская улица', 8),
#  ('улица Адмирала Макарова', 8),
#  ('улица Константина Царёва', 8),
#  ('Локомотивный проезд', 7),
#  ('Планетная улица', 7),
#  ('Новомосковская улица', 7),
#  ('Походный проезд', 7),
#  ('улица Алабяна', 7),
#  ('улица Космонавта Волкова', 7),
#  ('Карельский бульвар', 7),
#  ('Беговая улица', 7),
#  ('улица Заморёнова', 7),
#  ('Белозерская улица', 7),
#  ('улица Ивана Сусанина', 7),
#  ('улица Маршала Неделина', 7),
#  ('улица Конёнкова', 7),
#  ('Славянский бульвар', 7),
#  ('улица Грекова', 7),
#  ('улица Бестужевых', 7),
#  ('Сумской проезд', 7),
#  ('Большая Тульская улица', 7),
#  ('Олимпийский проспект', 7),
#  ('проезд Русанова', 7),
#  ('улица Докукина', 7),
#  ('Грайвороновская улица', 7),
#  ('Старая Басманная улица', 7),
#  ('улица Бирюсинка', 7),
#  ('Челябинская улица', 7),
#  ('Большой Купавенский проезд', 7),
#  ('5-я Парковая улица', 7),
#  ('улица Пречистенка', 7),
#  ('Красноармейская улица', 7),
#  ('Семёновский проезд', 7),
#  ('Новая Басманная улица', 7),
#  ('5-я Кабельная улица', 7),
#  ('улица Маршала Голованова', 7),
#  ('улица Горбунова', 7),
#  ('улица Коштоянца', 7),
#  ('улица Бутлерова', 7),
#  ('улица Винокурова', 7),
#  ('улица Маршала Шестопалова', 7),
#  ('6-я Радиальная улица', 7),
#  ('Новоцарицынское шоссе', 7),
#  ('Тропарёвская улица', 7),
#  ('Попутная улица', 7),
#  ('Новороссийская улица', 7),
#  ('Куликовская улица', 7),
#  ('улица Федосьино', 7),
#  ('улица Академика Комарова', 7),
#  ('Боровская улица', 7),
#  ('улица Логвиненко', 7),
#  ('Новокрюковская улица', 7),
#  ('Алабушевская улица', 7),
#  ('Святоозерская улица', 7),
#  ('улица Дмитриевского', 7),
#  ('Машкинское шоссе', 7),
#  ('улица Красная Сосна', 7),
#  ('проспект Защитников Москвы', 7),
#  ('Мещерский проспект', 7),
#  ('Колхозная улица', 7),
#  ('Чароитовая улица', 7),
#  ('Садовническая улица', 7),
#  ('улица Линии Октябрьской Железной Дороги', 6),
#  ('Автомоторная улица', 6),
#  ('Петровско-Разумовская аллея', 6),
#  ('Авангардная улица', 6),
#  ('Солнечногорская улица', 6),
#  ('улица Вучетича', 6),
#  ('Ижорская улица', 6),
#  ('улица Маршала Федоренко', 6),
#  ('улица Хамовнический Вал', 6),
#  ('улица 1905 Года', 6),
#  ('Химкинский бульвар', 6),
#  ('улица Маршала Василевского', 6),
#  ('улица Генерала Глаголева', 6),
#  ('Ростокинский проезд', 6),
#  ('Строгинское шоссе', 6),
#  ('улица Гамалеи', 6),
#  ('4-я Магистральная улица', 6),
#  ('Мурановская улица', 6),
#  ('Илимская улица', 6),
#  ('улица Говорова', 6),
#  ('Северодвинская улица', 6),
#  ('Тайнинская улица', 6),
#  ('Инженерная улица', 6),
#  ('Челюскинская улица', 6),
#  ('улица Академика Янгеля', 6),
#  ('Станционная улица', 6),
#  ('Кольская улица', 6),
#  ('улица Советской Армии', 6),
#  ('Краснопролетарская улица', 6),
#  ('Долгоруковская улица', 6),
#  ('Стрельбищенский переулок', 6),
#  ('Новорязанская улица', 6),
#  ('Большая Семёновская улица', 6),
#  ('Битцевский проезд', 6),
#  ('улица Большие Каменщики', 6),
#  ('улица Газопровод', 6),
#  ('Костомаровский переулок', 6),
#  ('Уссурийская улица', 6),
#  ('Красноярская улица', 6),
#  ('Фрязевская улица', 6),
#  ('Мартеновская улица', 6),
#  ('улица Плющева', 6),
#  ('Вольная улица', 6),
#  ('Измайловское шоссе', 6),
#  ('аллея Жемчуговой', 6),
#  ('Таганская улица', 6),
#  ('улица Маршала Тимошенко', 6),
#  ('1-я улица Машиностроения', 6),
#  ('Гоголевский бульвар', 6),
#  ('Москворецкая набережная', 6),
#  ('Воронцовская улица', 6),
#  ('Славянская площадь', 6),
#  ('Очаковское шоссе', 6),
#  ('Староволынская улица', 6),
#  ('Тверской бульвар', 6),
#  ('улица Остоженка', 6),
#  ('Подольская улица', 6),
#  ('Саратовская улица', 6),
#  ('Доброслободская улица', 6),
#  ('Никитинская улица', 6),
#  ('улица Рогожский Вал', 6),
#  ('Садовая-Кудринская улица', 6),
#  ('Большая Грузинская улица', 6),
#  ('Малая Грузинская улица', 6),
#  ('Хордовый проезд', 6),
#  ('Холодильный переулок', 6),
#  ('Иловайская улица', 6),
#  ('улица Медиков', 6),
#  ('Новохохловская улица', 6),
#  ('3-й Павелецкий проезд', 6),
#  ('Дербеневская набережная', 6),
#  ('Носовихинское шоссе', 6),
#  ('улица Довженко', 6),
#  ('улица Маршала Чуйкова', 6),
#  ('Нагорный проезд', 6),
#  ('Новокузнецкая улица', 6),
#  ('Пермская улица', 6),
#  ('улица Большая Ордынка', 6),
#  ('Чагинская улица', 6),
#  ('Соловьиный проезд', 6),
#  ('улица Академика Бакулева', 6),
#  ('2-я Магистральная улица', 6),
#  ('Старокачаловская улица', 6),
#  ('Производственная улица', 6),
#  ('Коктебельская улица', 6),
#  ('Чоботовская улица', 6),
#  ('Златоустовская улица', 6),
#  ('Международное шоссе', 6),
#  ('Остафьевская улица', 6),
#  ('Заповедная улица', 6),
#  ('Нижняя Красносельская улица', 6),
#  ('Большая Юшуньская улица', 6),
#  ('Юровская улица', 6),
#  ('Левобережная улица', 6),
#  ('улица Маршала Воробьёва', 6),
#  ('улица Гризодубовой', 6),
#  ('Солнечная аллея', 6),
#  ('улица Гоголя', 6),
#  ('Филаретовская улица', 6),
#  ('Островная улица', 6),
#  ('Вернисажная улица', 6),
#  ('Сухонская улица', 6),
#  ('Яковлевская улица', 6),
#  ('улица 40 лет Октября', 6),
#  ('Бачуринская улица', 6),
#  ('Автомобильный проезд', 6),
#  ('улица Зорге', 6),
#  ('Саввинская набережная', 6),
#  ('площадь Киевского Вокзала', 6),
#  ('Зимёнковская улица', 6),
#  ('Краснопрудная улица', 6),
#  ('Краснопресненская набережная', 6),
#  ('1-я Тверская-Ямская улица', 6),
#  ('Новодачная улица', 6),
#  ('Новосходненское шоссе', 6),
#  ('Погонный проезд', 6),
#  ('улица Костякова', 6),
#  ('улица Дубки', 6),
#  ('Малая Черкизовская улица', 6),
#  ('3-я Черепковская улица', 5),
#  ('Путейская улица', 5),
#  ('улица Клары Цеткин', 5),
#  ('Нарвская улица', 5),
#  ('улица Академика Курчатова', 5),
#  ('Краснополянская улица', 5),
#  ('улица Лавочкина', 5),
#  ('Звёздный бульвар', 5),
#  ('Красностуденческий проезд', 5),
#  ('улица Расплетина', 5),
#  ('2-я Квесисская улица', 5),
#  ('4-й Вятский переулок', 5),
#  ('улица Рогова', 5),
#  ('улица Маршала Новикова', 5),
#  ('3-я Магистральная улица', 5),
#  ('улица Вильгельма Пика', 5),
#  ('Олонецкая улица', 5),
#  ('2-й Хорошёвский проезд', 5),
#  ('Лианозовский проезд', 5),
#  ('улица Артамонова', 5),
#  ('Сумская улица', 5),
#  ('Вологодский проезд', 5),
#  ('улица Большая Якиманка', 5),
#  ('улица Мусоргского', 5),
#  ('Мирской переулок', 5),
#  ('улица Фонвизина', 5),
#  ('Печорская улица', 5),
#  ('улица Дурова', 5),
#  ('Ростокинская улица', 5),
#  ('улица Новинки', 5),
#  ('Щербаковская улица', 5),
#  ('улица Измайловский Вал', 5),
#  ('Большая Оленья улица', 5),
#  ('Затонная улица', 5),
#  ('Якорная улица', 5),
#  ('Котляковская улица', 5),
#  ('улица Сергия Радонежского', 5),
#  ('Новорогожская улица', 5),
#  ('Камчатская улица', 5),
#  ('3-й Самотёчный переулок', 5),
#  ('2-й Иртышский проезд', 5),
#  ('Электродная улица', 5),
#  ('улица Металлургов', 5),
#  ('улица Лазо', 5),
#  ('улица Ремизова', 5),
#  ('Тарусская улица', 5),
#  ('улица Василия Ботылёва', 5),
#  ('Бобруйская улица', 5),
#  ('7-я Парковая улица', 5),
#  ('улица Судакова', 5),
#  ('Тихорецкий бульвар', 5),
#  ('Лубянская площадь', 5),
#  ('улица Марии Ульяновой', 5),
#  ('улица Лебедева', 5),
#  ('Сущёвская улица', 5),
#  ('Паромная улица', 5),
#  ('Елецкая улица', 5),
#  ('Касимовская улица', 5),
#  ('Загорьевская улица', 5),
#  ('Новоспасский проезд', 5),
#  ('Ореховый проезд', 5),
#  ('Кустанайская улица', 5),
#  ('улица Строителей', 5),
#  ('Ухтомская улица', 5),
#  ('Пятницкая улица', 5),
#  ('Малая Тульская улица', 5),
#  ('Новоостаповская улица', 5),
#  ('улица Инессы Арманд', 5),
#  ('площадь Соловецких Юнг', 5),
#  ('улица Покрышкина', 5),
#  ('Домостроительная улица', 5),
#  ('Бесединское шоссе', 5),
#  ('улица Щорса', 5),
#  ('Новопеределкинская улица', 5),
#  ('Новоорловская улица', 5),
#  ('Луговой проезд', 5),
#  ('Красковская улица', 5),
#  ('Тихвинская улица', 5),
#  ('улица Проходчиков', 5),
#  ('улица Саморы Машела', 5),
#  ('Воротынская улица', 5),
#  ('улица Талалихина', 5),
#  ('улица Авиаконструктора Микояна', 5),
#  ('1-я Мясниковская улица', 5),
#  ('1-й Красногвардейский проезд', 5),
#  ('улица Михайловка', 5),
#  ('улица Конструктора Гуськова', 5),
#  ('улица Александровка', 5),
#  ('Малинская улица', 5),
#  ('Заводское шоссе', 5),
#  ('улица Лётчицы Тарасовой', 5),
#  ('улица Академика Алиханова', 5),
#  ('улица Рословка', 5),
#  ('улица Харлампиева', 5),
#  ('Рождественская улица', 5),
#  ('Клинская улица', 5),
#  ('1-й Пенягинский проезд', 5),
#  ('Озёрная аллея', 5),
#  ('улица Кибальчича', 5),
#  ('Раменский бульвар', 5),
#  ('Госпитальная улица', 5),
#  ('набережная Новикова-Прибоя', 5),
#  ('улица Корнея Чуковского', 5),
#  ('улица Маресьева', 5),
#  ('Новостроевская улица', 5),
#  ('улица Татьянин Парк', 5),
#  ('улица Ротерта', 5),
#  ('Цветной бульвар', 5),
#  ('2-я Бауманская улица', 5),
#  ('площадь Савёловского Вокзала', 5),
#  ('улица Лавриненко', 5),
#  ('улица Пырьева', 5),
#  ('улица Золоторожский Вал', 5),
#  ('Коптевский бульвар', 4),
#  ('4-й Новомихалковский проезд', 4),
#  ('1-й Волоколамский проезд', 4),
#  ('улица Усиевича', 4),
#  ('Часовая улица', 4),
#  ('улица Прянишникова', 4),
#  ('улица Бусиновская Горка', 4),
#  ('Новинский бульвар', 4),
#  ('Смоленский бульвар', 4),
#  ('Светлогорский проезд', 4),
#  ('улица Расковой', 4),
#  ('3-й Нижнелихоборский проезд', 4),
#  ('Рижская площадь', 4),
#  ('Старый Петровско-Разумовский проезд', 4),
#  ('Строительный проезд', 4),
#  ('Вишнёвая улица', 4),
#  ('Песчаная улица', 4),
#  ('Талдомская улица', 4),
#  ('Керамический проезд', 4),
#  ('улица Паршина', 4),
#  ('Шелепихинское шоссе', 4),
#  ('Отрадная улица', 4),
#  ('Шелепихинская набережная', 4),
#  ('улица Фомичёвой', 4),
#  ('92-й километр Московской Кольцевой Автодороги', 4),
#  ('улица Толбухина', 4),
#  ('Кременчугская улица', 4),
#  ('Воробьёвское шоссе', 4),
#  ('Новофилёвский проезд', 4),
#  ('Молдавская улица', 4),
#  ('улица Пестеля', 4),
#  ('Россошанский проезд', 4),
#  ('Россошанская улица', 4),
#  ('улица Гончарова', 4),
#  ('улица Двинцев', 4),
#  ('улица Грузинский Вал', 4),
#  ('Новый Берингов проезд', 4),
#  ('улица Сергея Макеева', 4),
#  ('Харьковская улица', 4),
#  ('улица Добролюбова', 4),
#  ('Большая Переяславская улица', 4),
#  ('улица Образцова', 4),
#  ('улица Новая Башиловка', 4),
#  ('Новоалексеевская улица', 4),
#  ('улица Преображенский Вал', 4),
#  ('улица Олений Вал', 4),
#  ('Большая Ширяевская улица', 4),
#  ('Миллионная улица', 4),
#  ('Вельяминовская улица', 4),
#  ('Халтуринская улица', 4),
#  ('Просторная улица', 4),
#  ('улица Ленинская Слобода', 4),
#  ('Преображенская улица', 4),
#  ('улица Бориса Жигулёнкова', 4),
#  ('улица Шумкина', 4),
#  ('Курганская улица', 4),
#  ('Чусовская улица', 4),
#  ('Одесская улица', 4),
#  ('улица Старый Гай', 4),
#  ('Напольный проезд', 4),
#  ('Электролитный проезд', 4),
#  ('Ясногорская улица', 4),
#  ('улица Айвазовского', 4),
#  ('улица Коновалова', 4),
#  ('Кузьминская улица', 4),
#  ('улица Зацепский Вал', 4),
#  ('Сормовская улица', 4),
#  ('Яузская улица', 4),
#  ('проезд Стройкомбината', 4),
#  ('Керченская улица', 4),
#  ('улица Шкулёва', 4),
#  ('Багратионовский проезд', 4),
#  ('Большая Андроньевская улица', 4),
#  ('Садовая-Спасская улица', 4),
#  ('Садовая-Самотёчная улица', 4),
#  ('Зубовский бульвар', 4),
#  ('улица Пржевальского', 4),
#  ('Новосущёвский переулок', 4),
#  ('улица Николая Химушина', 4),
#  ('Вильнюсская улица', 4),
#  ('улица Академика Хохлова', 4),
#  ('улица Паустовского', 4),
#  ('Конюшковская улица', 4),
#  ('улица Даниловский Вал', 4),
#  ('Ряжская улица', 4),
#  ('Луганская улица', 4),
#  ('улица Шверника', 4),
#  ('улица Гримау', 4),
#  ('Михневский проезд', 4),
#  ('Зеленодольская улица', 4),
#  ('Даниловская набережная', 4),
#  ('Юрьевский переулок', 4),
#  ('улица Орджоникидзе', 4),
#  ('Садовнический проезд', 4),
#  ('Устьинский проезд', 4),
#  ('Чистопрудный бульвар', 4),
#  ('Большой Москворецкий мост', 4),
#  ('улица Крупской', 4),
#  ('3-я Радиальная улица', 4),
#  ('34-й километр Московской Кольцевой Автодороги', 4),
#  ('32-й километр Московской Кольцевой Автодороги', 4),
#  ('проезд Одоевского', 4),
#  ('улица Раменки', 4),
#  ('улица Кедрова', 4),
#  ('7-я Кожуховская улица', 4),
#  ('Рочдельская улица', 4),
#  ('Инициативная улица', 4),
#  ('3-й Сыромятнический переулок', 4),
#  ('1-я Магистральная улица', 4),
#  ('Суворовская площадь', 4),
#  ('улица Комдива Орлова', 4),
#  ('Электрозаводский мост', 4),
#  ('1-й Митинский переулок', 4),
#  ('улица Академика Глушко', 4),
#  ('улица Знаменские Садки', 4),
#  ('Волынская улица', 4),
#  ('9-я Чоботовская аллея', 4),
#  ('Саранская улица', 4),
#  ('Лермонтовский проспект', 4),
#  ('Хвалынский бульвар', 4),
#  ('бульвар Адмирала Ушакова', 4),
#  ('улица Зарянова', 4),
#  ('Родионовская улица', 4),
#  ('Вятская улица', 4),
#  ('улица Академика Полякова', 4),
#  ('Цимлянская улица', 4),
#  ('улица Саломеи Нерис', 4),
#  ('1-й Котляковский переулок', 4),
#  ('улица Текстильщиков', 4),
#  ('Никулинский проезд', 4),
#  ('Комсомольская площадь', 4),
#  ('Середниковская улица', 4),
#  ('проезд № 474', 4),
#  ('улица Татьяны Макаровой', 4),
#  ('улица Панфилова', 4),
#  ('улица Бориса Петровского', 4),
#  ('9-я Северная линия', 4),
#  ('Новотушинский проезд', 4),
#  ('улица Маршала Прошлякова', 4),
#  ('Новодачное шоссе', 4),
#  ('улица Атласова', 4),
#  ('Мурманский проезд', 4),
#  ('улица Юлиана Семёнова', 4),
#  ('улица Липовый Парк', 4),
#  ('Смирновская улица', 4),
#  ('улица Лётчика Грицевца', 4),
#  ('Луховицкая улица', 4),
#  ('Энергетическая улица', 4),
#  ('улица Речников', 4),
#  ('Ягодная улица', 4),
#  ('Бутовский тупик', 4),
#  ('улица Анны Ахматовой', 4),
#  ('Николо-Хованская улица', 4),
#  ('улица Героя России Соломатина', 4),
#  ('улица Сретенка', 4),
#  ('площадь Тверская Застава', 4),
#  ('Садовая-Каретная улица', 4),
#  ('Смоленская набережная', 4),
#  ('Батюнинский проезд', 4),
#  ('Базовская улица', 4),
#  ('улица Вертолётчиков', 4),
#  ('улица Госпитальный Вал', 4),
#  ('Новоданиловская набережная', 4),
#  ('улица Космонавтов', 4),
#  ('улица Малая Дмитровка', 4),
#  ('улица Волхонка', 4),
#  ('18-й километр Московской Кольцевой Автодороги', 4),
#  ('улица Погодина', 4),
#  ('проспект Лихачёва', 4),
#  ('улица Пруд-Ключики', 4),
#  ('Дмитровский проезд', 4),
#  ('Лечебная улица', 4),
#  ('Потешная улица', 4),
#  ('улица Самуила Маршака', 4),
#  ('Федоскинская улица', 4),
#  ('Сосновая улица', 3),
#  ('2-я Хуторская улица', 3),
#  ('улица Лужники', 3),
#  ('Лужнецкая набережная', 3),
#  ('улица Саляма Адиля', 3),
#  ('Песчаная площадь', 3),
#  ('Минусинская улица', 3),
#  ('проезд Соломенной Сторожки', 3),
#  ('улица Максимова', 3),
#  ('Одинцовская улица', 3),
#  ('Ижорский проезд', 3),
#  ('улица Сергея Эйзенштейна', 3),
#  ('Отрадный проезд', 3),
#  ('Мелиховская улица', 3),
#  ('Псковская улица', 3),
#  ('Вяземская улица', 3),
#  ('улица Кубинка', 3),
#  ('Гвардейская улица', 3),
#  ('Староможайское шоссе', 3),
#  ('улица Серафимовича', 3),
#  ('Истринская улица', 3),
#  ('Заревый проезд', 3),
#  ('2-й Красногвардейский проезд', 3),
#  ('Мясницкая улица', 3),
#  ('Селезнёвская улица', 3),
#  ('улица Намёткина', 3),
#  ('Страстной бульвар', 3),
#  ('Семёновская площадь', 3),
#  ('Игральная улица', 3),
#  ('Велозаводская улица', 3),
#  ('улица Мастеркова', 3),
#  ('2-й Полевой переулок', 3),
#  ('2-й Котляковский переулок', 3),
#  ('улица Достоевского', 3),
#  ('Иркутская улица', 3),
#  ('Снайперская улица', 3),
#  ('улица Уткина', 3),
#  ('улица Паперника', 3),
#  ('Полоцкая улица', 3),
#  ('Обводное шоссе', 3),
#  ('улица Вострухина', 3),
#  ('Таганская площадь', 3),
#  ...]
